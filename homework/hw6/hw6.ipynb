# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as du
from torchvision import transforms as T
import os
import numpy as np
import time
from tqdm import tqdm
from torch.utils import data
import sidechainnet as scn
import einops
import gc

# %% [markdown]
# ## Build Model

# %%
class Dilation_block(nn.Module):
    def __init__(self, dilation):
        super(Dilation_block, self).__init__()

        self.bn1 = nn.BatchNorm2d(128)
        self.pd = nn.Conv2d(128, 64, 1)
        self.bn2 = nn.BatchNorm2d(64)
        self.d_conv = nn.Conv2d(64, 64, 1, dilation=dilation)
        self.bn3 = nn.BatchNorm2d(64)
        self.pu = nn.Conv2d(64, 128, 1)
    
    def forward(self, data):
        x = F.elu(self.bn1(data))
        x = self.pd(x)
        x = F.elu(self.bn2(x))
        x = self.d_conv(x)
        x = F.elu(self.bn3(x))
        x = self.pu(x)

        return x + data

# %%
class Dialation_blocks(nn.Module):
    def __init__(self):
        super(Dialation_blocks, self).__init__()

        self.db1 = Dilation_block(1)
        self.db2 = Dilation_block(2)
        self.db3 = Dilation_block(4)
        self.db4 = Dilation_block(8)
    
    def forward(self, data):
        x = self.db1(data)
        x = self.db2(x)
        x = self.db3(x)
        x = self.db4(x)

        return x

# %%
class Alphafold1(nn.Module):
    def __init__(self, num_blocks, device):
        super(Alphafold1, self).__init__()

        self.conv1 = nn.Conv2d(124, 128, 1)

        self.blocks = []
        for i in range(num_blocks):
            self.blocks.append(Dialation_blocks().to(device))

        self.conv2 = nn.Conv2d(128, 64, 1)

    def forward(self, data):
        x = self.conv1(data)
        
        for block in self.blocks:
            x = block(x)

        x = self.conv2(x)

        return x

# %% [markdown]
# ## Define Bin

# %%
bin = []
n = 2
gap = 20 / 64
while n < 22:
    bin.append(n)
    n += gap

# %% [markdown]
# ## Iterable Version of Training Dataset

# %%
from torch.utils.data import IterableDataset
import math
class Alphafold_iter_Dataset(IterableDataset):
    def __init__(self, data_block, dmats, dmat_masks, overlap=32):
        super(Alphafold_iter_Dataset).__init__()
        
        m = nn.ZeroPad2d(32)
        # change the data format to fit the input of conv2d
        self.data_block = einops.rearrange(data_block, 'b h w c-> b c h w')
        self.seq_len = self.data_block.size(dim=2)
        self.batch_size = self.data_block.size(dim=0)

        # zero padding the data block, distance map and mask
        self.data_block = m(self.data_block)
        self.dmats_p = m(dmats)
        self.dmat_masks_p = m(dmat_masks)
        
        self.overlap = overlap
        
    def __iter__(self):
        start_pos = torch.randint(32, (2,))
        start_pos = (int(start_pos[0]), int(start_pos[1]))
        pos_x, pos_y = start_pos
        if pos_x > pos_y:
            tmp = pos_x
            pos_x = pos_y
            pos_y = tmp
        for i in range(pos_x, self.seq_len, self.overlap):
            for j in range(pos_y, self.seq_len, self.overlap):
                seq_crop = T.functional.crop(self.data_block, i, j, 64, 64)
                dmat_crop = T.functional.crop(self.dmats_p, i, j, 64, 64)
                dmat_crop = np.searchsorted(bin, dmat_crop)
                dmat_crop[dmat_crop > 63] = 63
                dmat_crop = torch.tensor(dmat_crop.tolist())
                d_mask_crop = T.functional.crop(self.dmat_masks_p, i, j, 64, 64)
                for k in range(self.batch_size):
                    yield seq_crop[k], dmat_crop[k], d_mask_crop[k]
    
    def __len__(self):
        return (math.ceil(self.seq_len / self.overlap) ** 2) * self.batch_size

# %% [markdown]
# ## Define Dataset for Validation And Testing

# %%
class Alphafold_Dataset_Test(IterableDataset):
    def __init__(self, data_block, overlap=32):
        super(Alphafold_Dataset_Test).__init__()

        m = nn.ZeroPad2d(32)
        # change the data format to fit the input of conv2d
        self.data_block = einops.rearrange(data_block, 'b h w c-> b c h w')
        self.seq_len = self.data_block.size(dim=2)
        self.batch_size = self.data_block.size(dim=0)

        # zero padding the data block, distance map and mask
        self.data_block = m(self.data_block)
        self.overlap = overlap
        
    def __iter__(self):
        start_pos = torch.randint(32, (2,))
        start_pos = (int(start_pos[0]), int(start_pos[1]))
        pos_x, pos_y = start_pos
        if pos_x > pos_y:
            tmp = pos_x
            pos_x = pos_y
            pos_y = tmp
        if self.seq_len < 32:
            pos_x, pos_y = 0, 0
        for i in range(pos_x, self.seq_len, self.overlap):
            for j in range(pos_y, self.seq_len, self.overlap):
                seq_crop = T.functional.crop(self.data_block, i, j, 64, 64)
                for k in range(self.batch_size):
                    yield seq_crop[k], i, j
    
    def __len__(self):
        return (math.ceil(self.seq_len / self.overlap) ** 2) * self.batch_size

# %% [markdown]
# ## Load CASP7 data as pytorch tensors

# %%
data = scn.load(casp_version=7, with_pytorch="dataloaders", 
                seq_as_onehot=True, aggregate_model_input=False,
               batch_size=16)
# Out:
# SidechainNet was loaded from ./sidechainnet_data/sidechainnet_casp7_30.pkl.

# %% [markdown]
# ## Creates features for a batch of sequences

# %%
def get_seq_features(batch):
    '''
    Take a batch of sequence info and return the sequence (one-hot),
    evolutionary info and (phi, psi, omega) angles per position, 
    as well as position mask.
    Also return the distance matrix, and distance mask.
    '''
    str_seqs = batch.str_seqs # seq in str format
    seqs = batch.seqs # seq in one-hot format
    int_seqs = batch.int_seqs # seq in int format
    masks = batch.msks # which positions are valid
    lengths = batch.lengths # seq length
    evos = batch.evos # PSSM / evolutionary info
    angs = batch.angs[:,:,0:2] # torsion angles: phi, psi
    
    # use coords to create distance matrix from c-beta
    # except use c-alpha for G
    # coords[:, 4, :] is c-beta, and coords[:, 1, :] is c-alpha
    coords = batch.crds # seq coord info (all-atom)
    batch_xyz = []
    for i in range(coords.shape[0]):
        xyz = []
        xyz = [coords[i][cpos+4,:] 
                if masks[i][cpos//14] and str_seqs[i][cpos//14] != 'G'
                else coords[i][cpos+1,:]
                for cpos in range(0, coords[i].shape[0]-1, 14)]
        batch_xyz.append(torch.stack(xyz))
    batch_xyz = torch.stack(batch_xyz)
    # now create pairwise distance matrix
    dmats = torch.cdist(batch_xyz, batch_xyz)
    # create matrix mask (0 means i,j invalid)
    dmat_masks = torch.einsum('bi,bj->bij', masks, masks)
    
    return seqs, evos, angs, masks, dmats, dmat_masks

# %% [markdown]
# ## Model Save

# %%
def save_model(count, final_loss, model, optimizer):
    checkpoint = {
        'protein_num': count,
        'loss': final_loss,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict()}
    torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Function To Set Up Training

# %%
def train(data_block, dmats, dmat_masks, device, model, optimizer):
    batch_size = 20
    epochs = 5
    final_loss = None
    train_loader = du.DataLoader(dataset=Alphafold_iter_Dataset(data_block, 
                                dmats, dmat_masks), batch_size=batch_size)
    for epoch in range(1, epochs + 1):
        sum_loss = 0
        for batch_idx, (data, dmat, dmats_mask) in enumerate(train_loader):
            
            data, dmat, dmats_mask = data.to(device), \
            dmat.to(device), dmats_mask.to(device)
            optimizer.zero_grad()

            output = model(data)

            dmat = dmat * dmats_mask
            loss = F.cross_entropy(output, dmat)
            sum_loss += loss.item()
            loss.backward()
            optimizer.step()

            del data
            del output
            del dmat
            del dmats_mask
            gc.collect()

            #break
        final_loss = sum_loss / len(train_loader)
        print('epoch: {}, loss: {:.3f}'.format(epoch, final_loss))
        #break
    print('Final loss {:.3f}'.format(final_loss))
    return final_loss

# %% [markdown]
# ## Function For Validation and Testing

# %%
from sklearn.metrics import confusion_matrix
def get_recall(pred, true, seq_len):
    pred = np.array(pred)
    true = np.array(true)
    num_true = np.count_nonzero(pred > 0.5)
    denom = min(num_true, seq_len)
    short_pred_sort = np.argsort(-1*pred)
    short_pred_top = pred[short_pred_sort][0:denom]
    short_pred_top[short_pred_top>0.5] = 1
    short_pred_top[short_pred_top!=1] = 0
    short_true_top = true[short_pred_sort][0:denom]
    
    tn, fp, fn, tp = confusion_matrix(short_pred_top, short_true_top).ravel()
    res = None
    if tp+fp == 0:
        res = 0
    else:
        res = tp / (tp+fp)
    
    return res

# %%
recall_short_L = 0
recall_short_L_2 = 0
recall_short_L_5 = 0
recall_medium_L = 0
recall_medium_L_2 = 0
recall_medium_L_5 = 0
recall_long_L = 0
recall_long_L_2 = 0
recall_long_L_5 = 0
def valid_test(data_block, dmats, dmat_masks, device, model):
    batch_size = 1
    seq_len = data_block.size(dim=2)
    #print(seq_len)
    valid_loader = du.DataLoader(dataset=Alphafold_Dataset_Test(data_block), 
                                 batch_size=batch_size)
    
    #contact_true = np.searchsorted(bin, dmats)
    contact_true = torch.clone(dmats)
    contact_true[contact_true <= 8.0] = 1
    contact_true[contact_true != 1] = 0
    contact_true = torch.tensor(contact_true.tolist()[0]).to(torch.int)
    
    global recall_short_L
    global recall_short_L_2
    global recall_short_L_5
    global recall_medium_L
    global recall_medium_L_2
    global recall_medium_L_5
    global recall_long_L
    global recall_long_L_2
    global recall_long_L_5
    
    # store the tensors for the position when overlapping
    pos_tensor = dict()
    with torch.no_grad():
        for batch_idx, (data, pos_i, pos_j) in enumerate(valid_loader):
            data = data.to(device)
            
            output = model(data)
            output = F.softmax(output, dim=1)
            
            pos_i, pos_j = int(pos_i[0]), int(pos_j[0])
            
            for idx_i, (i) in enumerate(range(pos_i, pos_i+64)):
                for idx_j, (j) in enumerate(range(pos_j, pos_j+64)):
                    if (i, j) not in pos_tensor:
                        pos_tensor[(i, j)] = []
                        pos_tensor[(i, j)].append(output[0,:,idx_i,idx_j])
                    else:
                        pos_tensor[(i, j)].append(output[0,:,idx_i,idx_j])
    
    # compute the mean probability
    pred = []
    for i in range(32, 32+seq_len):
        row = []
        for j in range(32, 32+seq_len):
            pos_tensor[(i, j)] = sum(pos_tensor[(i, j)]) / \
                                len(pos_tensor[(i, j)])
            row.append(torch.sum(pos_tensor[(i, j)][0:20]))
        pred.append(row)
    
    pred = torch.tensor(pred)
    pred = pred * dmat_masks[0]
    
    short_pred = []
    short_true = []
    # short contact
    for i in range(6, 12):
        diag = torch.diagonal(pred, i, dim1=0, dim2=1)
        short_pred.extend(diag.tolist())
        diag = torch.diagonal(contact_true, i, dim1=0, dim2=1)
        short_true.extend(diag.tolist())
    
    # compute L size
    res = get_recall(short_pred, short_true, seq_len)
    recall_short_L += res
    
    # L / 2
    res = get_recall(short_pred, short_true, int(seq_len/2))
    recall_short_L_2 += res
    
    # L / 5
    res = get_recall(short_pred, short_true, int(seq_len/5))
    recall_short_L_5 += res
    
    medium_pred = []
    medium_true = []
    # medium contact
    for i in range(12, 24):
        diag = torch.diagonal(pred, i, dim1=0, dim2=1)
        medium_pred.extend(diag.tolist())
        diag = torch.diagonal(contact_true, i, dim1=0, dim2=1)
        medium_true.extend(diag.tolist())
    
    # compute L size
    res = get_recall(medium_pred, medium_true, seq_len)
    recall_medium_L += res
    
    # L / 2
    res = get_recall(medium_pred, medium_true, int(seq_len/2))
    recall_medium_L_2 += res
    
    # L / 5
    res = get_recall(medium_pred, medium_true, int(seq_len/5))
    recall_medium_L_5 += res
    
    long_pred = []
    long_true = []
    # long contact
    for i in range(24, seq_len):
        diag = torch.diagonal(pred, i, dim1=0, dim2=1)
        long_pred.extend(diag.tolist())
        diag = torch.diagonal(contact_true, i, dim1=0, dim2=1)
        long_true.extend(diag.tolist())
    
    # compute L size
    res = get_recall(long_pred, long_true, seq_len)
    recall_long_L += res
    
    # L / 2
    res = get_recall(long_pred, long_true, int(seq_len/2))
    recall_long_L_2 += res
    
    # L / 5
    res = get_recall(long_pred, long_true, int(seq_len/5))
    recall_long_L_5 += res

    return

# %% [markdown]
# ## Now iterate through the train data
#
# Do the same for data['test'] and data['valid-10']

# %%
count = 0
device = f'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f"using device: {device}")
# number of blocks needed
num_blocks = 2
model = Alphafold1(num_blocks, device)
model = model.to(device)
model.train()
optimizer = optim.SGD(model.parameters(), lr=0.06, momentum=0.9)
# Out:
# using device: cuda:0

# %%
for batch in data['train']:
    seqs, evos, angs, masks, dmats, dmat_masks = get_seq_features(batch)
    # print(seqs.shape, evos.shape, angs.shape, masks.shape)
    # print(dmats.shape, dmat_masks.shape)
    
    '''
    Now write code to create the crops from each protein in the batch
    to create the final batch of crops along with true "labels" 
    for the distances and angles.
    
    dmat should be discretized into 64 bins, and angs into 1296 bins, 
    as described in lecture, to create true labels/bins.
    
    The input to you model should only be the seqs, and evos features.
    Read sidechainnet github page for more info.
    '''
    # generate sequence block with L×L×f
    seq_len = seqs.size(dim=1)
    seqs_evos = torch.cat((seqs, evos), 2)
    #print(seqs_evos.shape)
    seq_block = torch.tensor(seq_len*[seqs_evos.tolist()])
    #print(seq_block.shape)
    seq_block = torch.transpose(seq_block, 0, 1)
    #seq_block = einops.rearrange(seq_block, 'l b h f -> b l h f')
    seq_block_t = torch.transpose(seq_block, 1, 2)
    seq_block = torch.cat((seq_block_t, seq_block), 3)

    evo_block = torch.tensor(seq_len*[evos.tolist()])
    evo_block = torch.transpose(evo_block, 0, 1)
    #evo_block = einops.rearrange(evo_block, 'l b h f -> b l h f')
    evo_block_t = torch.transpose(evo_block, 1, 2)
    final_block = torch.cat((seq_block, evo_block-evo_block_t, 
                             evo_block * evo_block_t), 3)

    print('protein number {}, length {}'.format(count, seq_len))
    # if seq_len > 800:
    #     continue

    final_loss = train(final_block, dmats, dmat_masks, device, model, optimizer)
    save_model(count, final_loss, model, optimizer)

    del seq_block
    del seq_block_t
    del final_block
    del evo_block
    del evo_block_t
    gc.collect()

    # if count == 0:
    #     break
    
    count += 1
# Out:
# using device: cuda:0
# protein number 0, length 498
# epoch: 1, loss: 1.732
# epoch: 2, loss: 1.641
# epoch: 3, loss: 1.458
# epoch: 4, loss: 1.508
# epoch: 5, loss: 1.472
# Final loss 1.472
# protein number 1, length 143
# epoch: 1, loss: 2.103
# epoch: 2, loss: 1.993
# epoch: 3, loss: 2.206
# epoch: 4, loss: 1.870
# epoch: 5, loss: 1.870
# Final loss 1.870
# protein number 2, length 497
# epoch: 1, loss: 1.468
# epoch: 2, loss: 1.448
# epoch: 3, loss: 1.468
# epoch: 4, loss: 1.435
# epoch: 5, loss: 1.380
# Final loss 1.380
# protein number 3, length 66
# epoch: 1, loss: 0.927
# epoch: 2, loss: 0.875
# epoch: 3, loss: 1.076
# epoch: 4, loss: 1.025
# epoch: 5, loss: 0.801
# Final loss 0.801
# protein number 4, length 266
# epoch: 1, loss: 1.835
# epoch: 2, loss: 1.704
# epoch: 3, loss: 1.693
# epoch: 4, loss: 1.703
# epoch: 5, loss: 1.804
# Final loss 1.804
# protein number 5, length 219
# epoch: 1, loss: 2.101
# epoch: 2, loss: 2.100
# epoch: 3, loss: 1.948
# epoch: 4, loss: 1.929
# epoch: 5, loss: 2.075
# Final loss 2.075
# protein number 6, length 128
# epoch: 1, loss: 2.248
# epoch: 2, loss: 2.210
# epoch: 3, loss: 2.233
# epoch: 4, loss: 2.228
# epoch: 5, loss: 2.178
# Final loss 2.178
# protein number 7, length 50
# epoch: 1, loss: 1.125
# epoch: 2, loss: 1.201
# epoch: 3, loss: 1.085
# epoch: 4, loss: 0.468
# epoch: 5, loss: 0.663
# Final loss 0.663
# protein number 8, length 297
# epoch: 1, loss: 1.789
# epoch: 2, loss: 1.654
# epoch: 3, loss: 1.642
# epoch: 4, loss: 1.638
# epoch: 5, loss: 1.694
# Final loss 1.694
# protein number 9, length 158
# epoch: 1, loss: 2.312
# epoch: 2, loss: 2.223
# epoch: 3, loss: 2.195
# epoch: 4, loss: 2.187
# epoch: 5, loss: 1.919
# Final loss 1.919
# protein number 10, length 66
# epoch: 1, loss: 0.801
# epoch: 2, loss: 0.743
# epoch: 3, loss: 0.980
# epoch: 4, loss: 0.753
# epoch: 5, loss: 0.726
# Final loss 0.726
# protein number 11, length 189
# epoch: 1, loss: 2.132
# epoch: 2, loss: 1.907
# epoch: 3, loss: 2.061
# epoch: 4, loss: 2.099
# epoch: 5, loss: 2.084
# Final loss 2.084
# protein number 12, length 219
# epoch: 1, loss: 2.077
# epoch: 2, loss: 2.028
# epoch: 3, loss: 2.015
# epoch: 4, loss: 2.045
# epoch: 5, loss: 2.023
# Final loss 2.023
# protein number 13, length 50
# epoch: 1, loss: 1.170
# epoch: 2, loss: 1.159
# epoch: 3, loss: 0.676
# epoch: 4, loss: 0.485
# epoch: 5, loss: 1.058
# Final loss 1.058
# protein number 14, length 66
# epoch: 1, loss: 1.038
# epoch: 2, loss: 0.785
# epoch: 3, loss: 0.798
# epoch: 4, loss: 0.755
# epoch: 5, loss: 0.790
# Final loss 0.790
# protein number 15, length 729
# epoch: 1, loss: 1.296
# epoch: 2, loss: 1.255
# epoch: 3, loss: 1.249
# epoch: 4, loss: 1.230
# epoch: 5, loss: 1.209
# Final loss 1.209
# protein number 16, length 220
# epoch: 1, loss: 2.215
# epoch: 2, loss: 2.180
# epoch: 3, loss: 2.143
# epoch: 4, loss: 2.082
# epoch: 5, loss: 2.090
# Final loss 2.090
# protein number 17, length 50
# epoch: 1, loss: 1.240
# epoch: 2, loss: 0.741
# epoch: 3, loss: 0.488
# epoch: 4, loss: 0.743
# epoch: 5, loss: 0.744
# Final loss 0.744
# protein number 18, length 97
# epoch: 1, loss: 1.227
# epoch: 2, loss: 1.226
# epoch: 3, loss: 1.140
# epoch: 4, loss: 1.219
# epoch: 5, loss: 1.213
# Final loss 1.213
# protein number 19, length 266
# epoch: 1, loss: 1.686
# epoch: 2, loss: 1.737
# epoch: 3, loss: 1.662
# epoch: 4, loss: 1.748
# epoch: 5, loss: 1.648
# Final loss 1.648
# protein number 20, length 216
# epoch: 1, loss: 2.118
# epoch: 2, loss: 1.957
# epoch: 3, loss: 1.941
# epoch: 4, loss: 1.949
# epoch: 5, loss: 2.078
# Final loss 2.078
# protein number 21, length 297
# epoch: 1, loss: 1.670
# epoch: 2, loss: 1.774
# epoch: 3, loss: 1.732
# epoch: 4, loss: 1.709
# epoch: 5, loss: 1.758
# Final loss 1.758
# protein number 22, length 236
# epoch: 1, loss: 1.909
# epoch: 2, loss: 1.994
# epoch: 3, loss: 1.729
# epoch: 4, loss: 1.948
# epoch: 5, loss: 1.838
# Final loss 1.838
# protein number 23, length 50
# epoch: 1, loss: 1.213
# epoch: 2, loss: 0.694
# epoch: 3, loss: 1.063
# epoch: 4, loss: 0.474
# epoch: 5, loss: 0.704
# Final loss 0.704
# protein number 24, length 234
# epoch: 1, loss: 1.675
# epoch: 2, loss: 1.675
# epoch: 3, loss: 1.786
# epoch: 4, loss: 1.876
# epoch: 5, loss: 1.854
# Final loss 1.854
# protein number 25, length 436
# epoch: 1, loss: 1.533
# epoch: 2, loss: 1.523
# epoch: 3, loss: 1.488
# epoch: 4, loss: 1.571
# epoch: 5, loss: 1.559
# Final loss 1.559
# protein number 26, length 97
# epoch: 1, loss: 1.242
# epoch: 2, loss: 1.197
# epoch: 3, loss: 1.168
# epoch: 4, loss: 1.151
# epoch: 5, loss: 1.166
# Final loss 1.166
# protein number 27, length 219
# epoch: 1, loss: 2.103
# epoch: 2, loss: 2.055
# epoch: 3, loss: 2.067
# epoch: 4, loss: 1.902
# epoch: 5, loss: 2.063
# Final loss 2.063
# protein number 28, length 81
# epoch: 1, loss: 1.160
# epoch: 2, loss: 1.449
# epoch: 3, loss: 1.427
# epoch: 4, loss: 1.825
# epoch: 5, loss: 1.412
# Final loss 1.412
# protein number 29, length 435
# epoch: 1, loss: 1.560
# epoch: 2, loss: 1.525
# epoch: 3, loss: 1.545
# epoch: 4, loss: 1.501
# epoch: 5, loss: 1.537
# Final loss 1.537
# protein number 30, length 313
# epoch: 1, loss: 1.944
# epoch: 2, loss: 1.927
# epoch: 3, loss: 1.932
# epoch: 4, loss: 1.786
# epoch: 5, loss: 1.858
# Final loss 1.858
# protein number 31, length 373
# epoch: 1, loss: 1.727
# epoch: 2, loss: 1.689
# epoch: 3, loss: 1.755
# epoch: 4, loss: 1.668
# epoch: 5, loss: 1.667
# Final loss 1.667
# protein number 32, length 111
# epoch: 1, loss: 1.631
# epoch: 2, loss: 1.622
# epoch: 3, loss: 1.388
# epoch: 4, loss: 1.802
# epoch: 5, loss: 1.586
# Final loss 1.586
# protein number 33, length 342
# epoch: 1, loss: 1.799
# epoch: 2, loss: 1.751
# epoch: 3, loss: 1.802
# epoch: 4, loss: 1.748
# epoch: 5, loss: 1.813
# Final loss 1.813
# protein number 34, length 35
# epoch: 1, loss: 0.205
# epoch: 2, loss: 0.199
# epoch: 3, loss: 0.195
# epoch: 4, loss: 0.192
# epoch: 5, loss: 0.191
# Final loss 0.191
# protein number 35, length 218
# epoch: 1, loss: 2.056
# epoch: 2, loss: 2.068
# epoch: 3, loss: 1.861
# epoch: 4, loss: 2.066
# epoch: 5, loss: 1.914
# Final loss 1.914
# protein number 36, length 356
# epoch: 1, loss: 1.650
# epoch: 2, loss: 1.634
# epoch: 3, loss: 1.625
# epoch: 4, loss: 1.617
# epoch: 5, loss: 1.667
# Final loss 1.667
# protein number 37, length 112
# epoch: 1, loss: 1.754
# epoch: 2, loss: 1.463
# epoch: 3, loss: 1.629
# epoch: 4, loss: 1.954
# epoch: 5, loss: 1.660
# Final loss 1.660
# protein number 38, length 434
# epoch: 1, loss: 1.617
# epoch: 2, loss: 1.576
# epoch: 3, loss: 1.564
# epoch: 4, loss: 1.535
# epoch: 5, loss: 1.560
# Final loss 1.560
# protein number 39, length 81
# epoch: 1, loss: 1.165
# epoch: 2, loss: 1.762
# epoch: 3, loss: 1.075
# epoch: 4, loss: 1.065
# epoch: 5, loss: 1.316
# Final loss 1.316
# protein number 40, length 35
# epoch: 1, loss: 0.384
# epoch: 2, loss: 0.191
# epoch: 3, loss: 0.190
# epoch: 4, loss: 0.372
# epoch: 5, loss: 0.188
# Final loss 0.188
# protein number 41, length 390
# epoch: 1, loss: 1.658
# epoch: 2, loss: 1.689
# epoch: 3, loss: 1.622
# epoch: 4, loss: 1.617
# epoch: 5, loss: 1.675
# Final loss 1.675
# protein number 42, length 174
# epoch: 1, loss: 1.849
# epoch: 2, loss: 1.701
# epoch: 3, loss: 1.694
# epoch: 4, loss: 2.025
# epoch: 5, loss: 2.023
# Final loss 2.023
# protein number 43, length 35
# epoch: 1, loss: 0.204
# epoch: 2, loss: 0.201
# epoch: 3, loss: 0.198
# epoch: 4, loss: 0.383
# epoch: 5, loss: 0.194
# Final loss 0.194
# protein number 44, length 189
# epoch: 1, loss: 2.226
# epoch: 2, loss: 2.190
# epoch: 3, loss: 2.046
# epoch: 4, loss: 2.210
# epoch: 5, loss: 2.228
# Final loss 2.228
# protein number 45, length 35
# epoch: 1, loss: 0.389
# epoch: 2, loss: 0.188
# epoch: 3, loss: 0.185
# epoch: 4, loss: 0.182
# epoch: 5, loss: 0.181
# Final loss 0.181
# protein number 46, length 158
# epoch: 1, loss: 1.986
# epoch: 2, loss: 2.182
# epoch: 3, loss: 2.177
# epoch: 4, loss: 2.183
# epoch: 5, loss: 2.152
# Final loss 2.152
# protein number 47, length 158
# epoch: 1, loss: 2.146
# epoch: 2, loss: 2.159
# epoch: 3, loss: 1.915
# epoch: 4, loss: 2.153
# epoch: 5, loss: 2.118
# Final loss 2.118
# protein number 48, length 128
# epoch: 1, loss: 2.287
# epoch: 2, loss: 2.213
# epoch: 3, loss: 2.154
# epoch: 4, loss: 2.147
# epoch: 5, loss: 2.250
# Final loss 2.250
# protein number 49, length 66
# epoch: 1, loss: 0.765
# epoch: 2, loss: 0.822
# epoch: 3, loss: 0.787
# epoch: 4, loss: 0.799
# epoch: 5, loss: 0.817
# Final loss 0.817
# protein number 50, length 35
# epoch: 1, loss: 0.193
# epoch: 2, loss: 0.189
# epoch: 3, loss: 0.187
# epoch: 4, loss: 0.187
# epoch: 5, loss: 0.186
# Final loss 0.186
# protein number 51, length 35
# epoch: 1, loss: 0.334
# epoch: 2, loss: 0.174
# epoch: 3, loss: 0.174
# epoch: 4, loss: 0.174
# epoch: 5, loss: 0.173
# Final loss 0.173
# protein number 52, length 128
# epoch: 1, loss: 2.274
# epoch: 2, loss: 2.226
# epoch: 3, loss: 2.269
# epoch: 4, loss: 2.166
# epoch: 5, loss: 2.257
# Final loss 2.257
# protein number 53, length 81
# epoch: 1, loss: 1.333
# epoch: 2, loss: 1.638
# epoch: 3, loss: 1.275
# epoch: 4, loss: 1.290
# epoch: 5, loss: 1.281
# Final loss 1.281
# protein number 54, length 81
# epoch: 1, loss: 1.705
# epoch: 2, loss: 1.350
# epoch: 3, loss: 1.370
# epoch: 4, loss: 1.382
# epoch: 5, loss: 1.380
# Final loss 1.380
# protein number 55, length 390
# epoch: 1, loss: 1.635
# epoch: 2, loss: 1.586
# epoch: 3, loss: 1.640
# epoch: 4, loss: 1.597
# epoch: 5, loss: 1.637
# Final loss 1.637
# protein number 56, length 513
# epoch: 1, loss: 1.340
# epoch: 2, loss: 1.326
# epoch: 3, loss: 1.327
# epoch: 4, loss: 1.320
# epoch: 5, loss: 1.297
# Final loss 1.297
# protein number 57, length 50
# epoch: 1, loss: 1.350
# epoch: 2, loss: 0.720
# epoch: 3, loss: 0.691
# epoch: 4, loss: 1.142
# epoch: 5, loss: 0.731
# Final loss 0.731
# protein number 58, length 233
# epoch: 1, loss: 1.719
# epoch: 2, loss: 1.815
# epoch: 3, loss: 1.811
# epoch: 4, loss: 1.808
# epoch: 5, loss: 1.814
# Final loss 1.814
# protein number 59, length 143
# epoch: 1, loss: 1.674
# epoch: 2, loss: 1.801
# epoch: 3, loss: 1.760
# epoch: 4, loss: 1.761
# epoch: 5, loss: 1.761
# Final loss 1.761
# protein number 60, length 158
# epoch: 1, loss: 2.128
# epoch: 2, loss: 2.113
# epoch: 3, loss: 2.091
# epoch: 4, loss: 2.062
# epoch: 5, loss: 2.085
# Final loss 2.085
# protein number 61, length 66
# epoch: 1, loss: 0.800
# epoch: 2, loss: 0.781
# epoch: 3, loss: 0.751
# epoch: 4, loss: 0.765
# epoch: 5, loss: 0.962
# Final loss 0.962
# protein number 62, length 218
# epoch: 1, loss: 2.021
# epoch: 2, loss: 1.826
# epoch: 3, loss: 1.963
# epoch: 4, loss: 1.843
# epoch: 5, loss: 1.981
# Final loss 1.981
# protein number 63, length 527
# epoch: 1, loss: 1.481
# epoch: 2, loss: 1.464
# epoch: 3, loss: 1.469
# epoch: 4, loss: 1.428
# epoch: 5, loss: 1.465
# Final loss 1.465
# protein number 64, length 297
# epoch: 1, loss: 1.751
# epoch: 2, loss: 1.666
# epoch: 3, loss: 1.661
# epoch: 4, loss: 1.717
# epoch: 5, loss: 1.645
# Final loss 1.645
# protein number 65, length 588
# epoch: 1, loss: 1.181
# epoch: 2, loss: 1.165
# epoch: 3, loss: 1.164
# epoch: 4, loss: 1.201
# epoch: 5, loss: 1.202
# Final loss 1.202
# protein number 66, length 143
# epoch: 1, loss: 1.736
# epoch: 2, loss: 1.822
# epoch: 3, loss: 1.791
# epoch: 4, loss: 1.620
# epoch: 5, loss: 1.612
# Final loss 1.612
# protein number 67, length 158
# epoch: 1, loss: 2.225
# epoch: 2, loss: 1.972
# epoch: 3, loss: 2.190
# epoch: 4, loss: 2.179
# epoch: 5, loss: 2.190
# Final loss 2.190
# protein number 68, length 128
# epoch: 1, loss: 2.174
# epoch: 2, loss: 2.165
# epoch: 3, loss: 2.192
# epoch: 4, loss: 2.129
# epoch: 5, loss: 2.131
# Final loss 2.131
# protein number 69, length 328
# epoch: 1, loss: 1.655
# epoch: 2, loss: 1.703
# epoch: 3, loss: 1.634
# epoch: 4, loss: 1.622
# epoch: 5, loss: 1.696
# Final loss 1.696
# protein number 70, length 296
# epoch: 1, loss: 1.653
# epoch: 2, loss: 1.652
# epoch: 3, loss: 1.696
# epoch: 4, loss: 1.699
# epoch: 5, loss: 1.636
# Final loss 1.636
# protein number 71, length 128
# epoch: 1, loss: 2.386
# epoch: 2, loss: 2.292
# epoch: 3, loss: 2.316
# epoch: 4, loss: 2.221
# epoch: 5, loss: 2.294
# Final loss 2.294
# protein number 72, length 738
# epoch: 1, loss: 1.269
# epoch: 2, loss: 1.283
# epoch: 3, loss: 1.296
# epoch: 4, loss: 1.260
# epoch: 5, loss: 1.245
# Final loss 1.245
# protein number 73, length 205
# epoch: 1, loss: 1.855
# epoch: 2, loss: 1.811
# epoch: 3, loss: 1.784
# epoch: 4, loss: 1.925
# epoch: 5, loss: 1.920
# Final loss 1.920
# protein number 74, length 174
# epoch: 1, loss: 1.550
# epoch: 2, loss: 1.817
# epoch: 3, loss: 1.611
# epoch: 4, loss: 1.610
# epoch: 5, loss: 1.601
# Final loss 1.601
# protein number 75, length 388
# epoch: 1, loss: 1.534
# epoch: 2, loss: 1.509
# epoch: 3, loss: 1.501
# epoch: 4, loss: 1.551
# epoch: 5, loss: 1.505
# Final loss 1.505
# protein number 76, length 421
# epoch: 1, loss: 1.535
# epoch: 2, loss: 1.610
# epoch: 3, loss: 1.513
# epoch: 4, loss: 1.499
# epoch: 5, loss: 1.494
# Final loss 1.494
# protein number 77, length 143
# epoch: 1, loss: 2.034
# epoch: 2, loss: 1.586
# epoch: 3, loss: 1.583
# epoch: 4, loss: 1.749
# epoch: 5, loss: 1.576
# Final loss 1.576
# protein number 78, length 81
# epoch: 1, loss: 1.088
# epoch: 2, loss: 1.061
# epoch: 3, loss: 1.312
# epoch: 4, loss: 1.046
# epoch: 5, loss: 1.637
# Final loss 1.637
# protein number 79, length 174
# epoch: 1, loss: 1.796
# epoch: 2, loss: 1.817
# epoch: 3, loss: 1.834
# epoch: 4, loss: 1.673
# epoch: 5, loss: 1.796
# Final loss 1.796
# protein number 80, length 282
# epoch: 1, loss: 1.957
# epoch: 2, loss: 1.904
# epoch: 3, loss: 1.909
# epoch: 4, loss: 1.836
# epoch: 5, loss: 1.945
# Final loss 1.945
# protein number 81, length 188
# epoch: 1, loss: 2.250
# epoch: 2, loss: 2.019
# epoch: 3, loss: 2.202
# epoch: 4, loss: 2.208
# epoch: 5, loss: 2.018
# Final loss 2.018
# protein number 82, length 498
# epoch: 1, loss: 1.538
# epoch: 2, loss: 1.447
# epoch: 3, loss: 1.458
# epoch: 4, loss: 1.465
# epoch: 5, loss: 1.505
# Final loss 1.505
# protein number 83, length 264
# epoch: 1, loss: 1.897
# epoch: 2, loss: 1.691
# epoch: 3, loss: 1.778
# epoch: 4, loss: 1.793
# epoch: 5, loss: 1.790
# Final loss 1.790
# protein number 84, length 128
# epoch: 1, loss: 2.179
# epoch: 2, loss: 2.194
# epoch: 3, loss: 2.225
# epoch: 4, loss: 2.237
# epoch: 5, loss: 2.139
# Final loss 2.139
# protein number 85, length 235
# epoch: 1, loss: 1.729
# epoch: 2, loss: 1.841
# epoch: 3, loss: 1.837
# epoch: 4, loss: 1.702
# epoch: 5, loss: 1.695
# Final loss 1.695
# protein number 86, length 497
# epoch: 1, loss: 1.394
# epoch: 2, loss: 1.384
# epoch: 3, loss: 1.360
# epoch: 4, loss: 1.429
# epoch: 5, loss: 1.377
# Final loss 1.377
# protein number 87, length 81
# epoch: 1, loss: 1.948
# epoch: 2, loss: 1.442
# epoch: 3, loss: 1.392
# epoch: 4, loss: 1.104
# epoch: 5, loss: 1.831
# Final loss 1.831
# protein number 88, length 81
# epoch: 1, loss: 1.066
# epoch: 2, loss: 1.763
# epoch: 3, loss: 1.043
# epoch: 4, loss: 1.341
# epoch: 5, loss: 1.675
# Final loss 1.675
# protein number 89, length 328
# epoch: 1, loss: 1.704
# epoch: 2, loss: 1.592
# epoch: 3, loss: 1.588
# epoch: 4, loss: 1.581
# epoch: 5, loss: 1.586
# Final loss 1.586
# protein number 90, length 205
# epoch: 1, loss: 1.779
# epoch: 2, loss: 1.619
# epoch: 3, loss: 1.873
# epoch: 4, loss: 1.768
# epoch: 5, loss: 1.612
# Final loss 1.612
# protein number 91, length 125
# epoch: 1, loss: 2.196
# epoch: 2, loss: 2.163
# epoch: 3, loss: 2.153
# epoch: 4, loss: 2.098
# epoch: 5, loss: 2.128
# Final loss 2.128
# protein number 92, length 342
# epoch: 1, loss: 1.794
# epoch: 2, loss: 1.721
# epoch: 3, loss: 1.724
# epoch: 4, loss: 1.780
# epoch: 5, loss: 1.715
# Final loss 1.715
# protein number 93, length 219
# epoch: 1, loss: 2.062
# epoch: 2, loss: 1.998
# epoch: 3, loss: 1.864
# epoch: 4, loss: 1.971
# epoch: 5, loss: 1.993
# Final loss 1.993
# protein number 94, length 81
# epoch: 1, loss: 1.842
# epoch: 2, loss: 1.423
# epoch: 3, loss: 1.426
# epoch: 4, loss: 1.381
# epoch: 5, loss: 1.371
# Final loss 1.371
# protein number 95, length 405
# epoch: 1, loss: 1.734
# epoch: 2, loss: 1.645
# epoch: 3, loss: 1.630
# epoch: 4, loss: 1.613
# epoch: 5, loss: 1.607
# Final loss 1.607
# protein number 96, length 373
# epoch: 1, loss: 1.791
# epoch: 2, loss: 1.767
# epoch: 3, loss: 1.702
# epoch: 4, loss: 1.694
# epoch: 5, loss: 1.762
# Final loss 1.762
# protein number 97, length 250
# epoch: 1, loss: 1.897
# epoch: 2, loss: 2.001
# epoch: 3, loss: 1.995
# epoch: 4, loss: 1.871
# epoch: 5, loss: 1.994
# Final loss 1.994
# protein number 98, length 112
# epoch: 1, loss: 1.488
# epoch: 2, loss: 1.676
# epoch: 3, loss: 1.655
# epoch: 4, loss: 1.428
# epoch: 5, loss: 1.626
# Final loss 1.626
# protein number 99, length 251
# epoch: 1, loss: 1.957
# epoch: 2, loss: 2.036
# epoch: 3, loss: 1.893
# epoch: 4, loss: 1.918
# epoch: 5, loss: 1.912
# Final loss 1.912
# protein number 100, length 789
# epoch: 1, loss: 1.237
# epoch: 2, loss: 1.239
# epoch: 3, loss: 1.231
# epoch: 4, loss: 1.235
# epoch: 5, loss: 1.232
# Final loss 1.232
# protein number 101, length 97
# epoch: 1, loss: 1.380
# epoch: 2, loss: 1.249
# epoch: 3, loss: 1.224
# epoch: 4, loss: 1.172
# epoch: 5, loss: 1.178
# Final loss 1.178
# protein number 102, length 356
# epoch: 1, loss: 1.648
# epoch: 2, loss: 1.626
# epoch: 3, loss: 1.631
# epoch: 4, loss: 1.619
# epoch: 5, loss: 1.619
# Final loss 1.619
# protein number 103, length 112
# epoch: 1, loss: 2.095
# epoch: 2, loss: 1.457
# epoch: 3, loss: 1.676
# epoch: 4, loss: 1.659
# epoch: 5, loss: 1.651
# Final loss 1.651
# protein number 104, length 66
# epoch: 1, loss: 0.795
# epoch: 2, loss: 0.780
# epoch: 3, loss: 0.763
# epoch: 4, loss: 0.733
# epoch: 5, loss: 0.763
# Final loss 0.763
# protein number 105, length 249
# epoch: 1, loss: 1.921
# epoch: 2, loss: 1.780
# epoch: 3, loss: 1.899
# epoch: 4, loss: 1.759
# epoch: 5, loss: 1.760
# Final loss 1.760
# protein number 106, length 35
# epoch: 1, loss: 0.198
# epoch: 2, loss: 0.190
# epoch: 3, loss: 0.181
# epoch: 4, loss: 0.350
# epoch: 5, loss: 0.334
# Final loss 0.334
# protein number 107, length 112
# epoch: 1, loss: 2.016
# epoch: 2, loss: 1.442
# epoch: 3, loss: 1.666
# epoch: 4, loss: 1.662
# epoch: 5, loss: 1.422
# Final loss 1.422
# protein number 108, length 387
# epoch: 1, loss: 1.546
# epoch: 2, loss: 1.531
# epoch: 3, loss: 1.523
# epoch: 4, loss: 1.526
# epoch: 5, loss: 1.516
# Final loss 1.516
# protein number 109, length 97
# epoch: 1, loss: 1.307
# epoch: 2, loss: 1.197
# epoch: 3, loss: 1.227
# epoch: 4, loss: 1.169
# epoch: 5, loss: 1.170
# Final loss 1.170
# protein number 110, length 50
# epoch: 1, loss: 0.756
# epoch: 2, loss: 0.495
# epoch: 3, loss: 1.198
# epoch: 4, loss: 1.169
# epoch: 5, loss: 1.205
# Final loss 1.205
# protein number 111, length 66
# epoch: 1, loss: 0.746
# epoch: 2, loss: 0.770
# epoch: 3, loss: 0.767
# epoch: 4, loss: 0.778
# epoch: 5, loss: 0.770
# Final loss 0.770
# protein number 112, length 66
# epoch: 1, loss: 0.800
# epoch: 2, loss: 0.769
# epoch: 3, loss: 0.779
# epoch: 4, loss: 0.796
# epoch: 5, loss: 0.795
# Final loss 0.795
# protein number 113, length 142
# epoch: 1, loss: 2.036
# epoch: 2, loss: 1.620
# epoch: 3, loss: 2.015
# epoch: 4, loss: 1.616
# epoch: 5, loss: 1.779
# Final loss 1.779
# protein number 114, length 328
# epoch: 1, loss: 1.696
# epoch: 2, loss: 1.665
# epoch: 3, loss: 1.656
# epoch: 4, loss: 1.654
# epoch: 5, loss: 1.655
# Final loss 1.655
# protein number 115, length 50
# epoch: 1, loss: 1.272
# epoch: 2, loss: 0.548
# epoch: 3, loss: 0.542
# epoch: 4, loss: 0.540
# epoch: 5, loss: 1.219
# Final loss 1.219
# protein number 116, length 248
# epoch: 1, loss: 2.077
# epoch: 2, loss: 1.916
# epoch: 3, loss: 2.012
# epoch: 4, loss: 1.896
# epoch: 5, loss: 2.020
# Final loss 2.020
# protein number 117, length 174
# epoch: 1, loss: 1.761
# epoch: 2, loss: 1.757
# epoch: 3, loss: 1.750
# epoch: 4, loss: 1.713
# epoch: 5, loss: 1.739
# Final loss 1.739
# protein number 118, length 50
# epoch: 1, loss: 0.523
# epoch: 2, loss: 1.116
# epoch: 3, loss: 1.150
# epoch: 4, loss: 0.711
# epoch: 5, loss: 0.748
# Final loss 0.748
# protein number 119, length 218
# epoch: 1, loss: 1.879
# epoch: 2, loss: 2.051
# epoch: 3, loss: 2.039
# epoch: 4, loss: 2.024
# epoch: 5, loss: 1.852
# Final loss 1.852
# protein number 120, length 128
# epoch: 1, loss: 2.317
# epoch: 2, loss: 2.293
# epoch: 3, loss: 2.184
# epoch: 4, loss: 2.182
# epoch: 5, loss: 2.284
# Final loss 2.284
# protein number 121, length 356
# epoch: 1, loss: 1.598
# epoch: 2, loss: 1.502
# epoch: 3, loss: 1.564
# epoch: 4, loss: 1.550
# epoch: 5, loss: 1.498
# Final loss 1.498
# protein number 122, length 157
# epoch: 1, loss: 2.311
# epoch: 2, loss: 2.237
# epoch: 3, loss: 2.145
# epoch: 4, loss: 2.222
# epoch: 5, loss: 1.963
# Final loss 1.963
# protein number 123, length 112
# epoch: 1, loss: 1.672
# epoch: 2, loss: 1.958
# epoch: 3, loss: 1.439
# epoch: 4, loss: 1.438
# epoch: 5, loss: 1.646
# Final loss 1.646
# protein number 124, length 327
# epoch: 1, loss: 1.598
# epoch: 2, loss: 1.577
# epoch: 3, loss: 1.572
# epoch: 4, loss: 1.649
# epoch: 5, loss: 1.566
# Final loss 1.566
# protein number 125, length 143
# epoch: 1, loss: 1.661
# epoch: 2, loss: 1.637
# epoch: 3, loss: 1.626
# epoch: 4, loss: 1.775
# epoch: 5, loss: 1.799
# Final loss 1.799
# protein number 126, length 81
# epoch: 1, loss: 1.409
# epoch: 2, loss: 1.738
# epoch: 3, loss: 1.349
# epoch: 4, loss: 1.365
# epoch: 5, loss: 1.334
# Final loss 1.334
# protein number 127, length 112
# epoch: 1, loss: 1.667
# epoch: 2, loss: 1.692
# epoch: 3, loss: 1.453
# epoch: 4, loss: 1.450
# epoch: 5, loss: 1.679
# Final loss 1.679
# protein number 128, length 463
# epoch: 1, loss: 1.563
# epoch: 2, loss: 1.520
# epoch: 3, loss: 1.514
# epoch: 4, loss: 1.504
# epoch: 5, loss: 1.471
# Final loss 1.471
# protein number 129, length 35
# epoch: 1, loss: 0.210
# epoch: 2, loss: 0.196
# epoch: 3, loss: 0.196
# epoch: 4, loss: 0.187
# epoch: 5, loss: 0.184
# Final loss 0.184
# protein number 130, length 142
# epoch: 1, loss: 1.676
# epoch: 2, loss: 1.652
# epoch: 3, loss: 1.808
# epoch: 4, loss: 1.779
# epoch: 5, loss: 1.803
# Final loss 1.803
# protein number 131, length 97
# epoch: 1, loss: 1.211
# epoch: 2, loss: 1.179
# epoch: 3, loss: 1.145
# epoch: 4, loss: 1.169
# epoch: 5, loss: 1.196
# Final loss 1.196
# protein number 132, length 35
# epoch: 1, loss: 0.357
# epoch: 2, loss: 0.351
# epoch: 3, loss: 0.179
# epoch: 4, loss: 0.179
# epoch: 5, loss: 0.178
# Final loss 0.178
# protein number 133, length 158
# epoch: 1, loss: 2.285
# epoch: 2, loss: 2.254
# epoch: 3, loss: 2.011
# epoch: 4, loss: 2.251
# epoch: 5, loss: 2.251
# Final loss 2.251
# protein number 134, length 220
# epoch: 1, loss: 2.102
# epoch: 2, loss: 2.019
# epoch: 3, loss: 2.034
# epoch: 4, loss: 2.059
# epoch: 5, loss: 2.013
# Final loss 2.013
# protein number 135, length 66
# epoch: 1, loss: 0.819
# epoch: 2, loss: 0.806
# epoch: 3, loss: 1.035
# epoch: 4, loss: 0.805
# epoch: 5, loss: 0.803
# Final loss 0.803
# protein number 136, length 128
# epoch: 1, loss: 2.203
# epoch: 2, loss: 2.177
# epoch: 3, loss: 2.173
# epoch: 4, loss: 2.162
# epoch: 5, loss: 2.171
# Final loss 2.171
# protein number 137, length 571
# epoch: 1, loss: 1.535
# epoch: 2, loss: 1.500
# epoch: 3, loss: 1.493
# epoch: 4, loss: 1.493
# epoch: 5, loss: 1.466
# Final loss 1.466
# protein number 138, length 218
# epoch: 1, loss: 2.069
# epoch: 2, loss: 2.158
# epoch: 3, loss: 1.876
# epoch: 4, loss: 2.142
# epoch: 5, loss: 2.154
# Final loss 2.154
# protein number 139, length 112
# epoch: 1, loss: 2.076
# epoch: 2, loss: 1.474
# epoch: 3, loss: 1.676
# epoch: 4, loss: 1.636
# epoch: 5, loss: 1.652
# Final loss 1.652
# protein number 140, length 189
# epoch: 1, loss: 2.176
# epoch: 2, loss: 2.165
# epoch: 3, loss: 1.973
# epoch: 4, loss: 2.110
# epoch: 5, loss: 2.107
# Final loss 2.107
# protein number 141, length 173
# epoch: 1, loss: 1.674
# epoch: 2, loss: 1.676
# epoch: 3, loss: 1.797
# epoch: 4, loss: 1.757
# epoch: 5, loss: 1.934
# Final loss 1.934
# protein number 142, length 433
# epoch: 1, loss: 1.467
# epoch: 2, loss: 1.475
# epoch: 3, loss: 1.465
# epoch: 4, loss: 1.458
# epoch: 5, loss: 1.453
# Final loss 1.453
# protein number 143, length 81
# epoch: 1, loss: 1.857
# epoch: 2, loss: 1.385
# epoch: 3, loss: 1.088
# epoch: 4, loss: 1.736
# epoch: 5, loss: 1.808
# Final loss 1.808
# protein number 144, length 50
# epoch: 1, loss: 0.773
# epoch: 2, loss: 0.790
# epoch: 3, loss: 1.170
# epoch: 4, loss: 0.787
# epoch: 5, loss: 1.115
# Final loss 1.115
# protein number 145, length 174
# epoch: 1, loss: 1.893
# epoch: 2, loss: 1.898
# epoch: 3, loss: 1.894
# epoch: 4, loss: 1.624
# epoch: 5, loss: 1.727
# Final loss 1.727
# protein number 146, length 158
# epoch: 1, loss: 2.236
# epoch: 2, loss: 2.190
# epoch: 3, loss: 2.190
# epoch: 4, loss: 2.215
# epoch: 5, loss: 2.161
# Final loss 2.161
# protein number 147, length 111
# epoch: 1, loss: 1.910
# epoch: 2, loss: 1.633
# epoch: 3, loss: 1.581
# epoch: 4, loss: 1.634
# epoch: 5, loss: 1.591
# Final loss 1.591
# protein number 148, length 189
# epoch: 1, loss: 1.994
# epoch: 2, loss: 2.179
# epoch: 3, loss: 1.955
# epoch: 4, loss: 2.173
# epoch: 5, loss: 2.138
# Final loss 2.138
# protein number 149, length 66
# epoch: 1, loss: 0.823
# epoch: 2, loss: 1.040
# epoch: 3, loss: 0.757
# epoch: 4, loss: 0.793
# epoch: 5, loss: 0.952
# Final loss 0.952
# protein number 150, length 312
# epoch: 1, loss: 1.911
# epoch: 2, loss: 1.893
# epoch: 3, loss: 1.802
# epoch: 4, loss: 1.853
# epoch: 5, loss: 1.726
# Final loss 1.726
# protein number 151, length 312
# epoch: 1, loss: 1.660
# epoch: 2, loss: 1.695
# epoch: 3, loss: 1.634
# epoch: 4, loss: 1.780
# epoch: 5, loss: 1.630
# Final loss 1.630
# protein number 152, length 97
# epoch: 1, loss: 1.248
# epoch: 2, loss: 1.421
# epoch: 3, loss: 1.231
# epoch: 4, loss: 1.222
# epoch: 5, loss: 1.183
# Final loss 1.183
# protein number 153, length 529
# epoch: 1, loss: 1.529
# epoch: 2, loss: 1.481
# epoch: 3, loss: 1.482
# epoch: 4, loss: 1.426
# epoch: 5, loss: 1.392
# Final loss 1.392
# protein number 154, length 296
# epoch: 1, loss: 1.699
# epoch: 2, loss: 1.749
# epoch: 3, loss: 1.816
# epoch: 4, loss: 1.726
# epoch: 5, loss: 1.660
# Final loss 1.660
# protein number 155, length 66
# epoch: 1, loss: 0.830
# epoch: 2, loss: 0.818
# epoch: 3, loss: 0.788
# epoch: 4, loss: 0.790
# epoch: 5, loss: 1.007
# Final loss 1.007
# protein number 156, length 236
# epoch: 1, loss: 1.831
# epoch: 2, loss: 1.805
# epoch: 3, loss: 1.668
# epoch: 4, loss: 1.781
# epoch: 5, loss: 1.896
# Final loss 1.896
# protein number 157, length 312
# epoch: 1, loss: 1.889
# epoch: 2, loss: 1.705
# epoch: 3, loss: 1.852
# epoch: 4, loss: 1.756
# epoch: 5, loss: 1.749
# Final loss 1.749
# protein number 158, length 81
# epoch: 1, loss: 1.415
# epoch: 2, loss: 1.084
# epoch: 3, loss: 1.331
# epoch: 4, loss: 1.350
# epoch: 5, loss: 1.376
# Final loss 1.376
# protein number 159, length 97
# epoch: 1, loss: 1.212
# epoch: 2, loss: 1.197
# epoch: 3, loss: 1.220
# epoch: 4, loss: 1.222
# epoch: 5, loss: 1.162
# Final loss 1.162
# protein number 160, length 205
# epoch: 1, loss: 2.008
# epoch: 2, loss: 1.692
# epoch: 3, loss: 1.686
# epoch: 4, loss: 1.821
# epoch: 5, loss: 1.686
# Final loss 1.686
# protein number 161, length 143
# epoch: 1, loss: 2.023
# epoch: 2, loss: 1.608
# epoch: 3, loss: 1.770
# epoch: 4, loss: 1.609
# epoch: 5, loss: 1.751
# Final loss 1.751
# protein number 162, length 97
# epoch: 1, loss: 1.221
# epoch: 2, loss: 1.256
# epoch: 3, loss: 1.222
# epoch: 4, loss: 1.254
# epoch: 5, loss: 1.451
# Final loss 1.451
# protein number 163, length 81
# epoch: 1, loss: 1.365
# epoch: 2, loss: 1.386
# epoch: 3, loss: 1.777
# epoch: 4, loss: 1.397
# epoch: 5, loss: 1.790
# Final loss 1.790
# protein number 164, length 35
# epoch: 1, loss: 0.172
# epoch: 2, loss: 0.169
# epoch: 3, loss: 0.166
# epoch: 4, loss: 0.165
# epoch: 5, loss: 0.164
# Final loss 0.164
# protein number 165, length 140
# epoch: 1, loss: 1.600
# epoch: 2, loss: 1.726
# epoch: 3, loss: 1.577
# epoch: 4, loss: 1.570
# epoch: 5, loss: 1.570
# Final loss 1.570
# protein number 166, length 143
# epoch: 1, loss: 1.831
# epoch: 2, loss: 1.805
# epoch: 3, loss: 1.638
# epoch: 4, loss: 1.809
# epoch: 5, loss: 1.635
# Final loss 1.635
# protein number 167, length 158
# epoch: 1, loss: 2.252
# epoch: 2, loss: 2.222
# epoch: 3, loss: 1.987
# epoch: 4, loss: 2.219
# epoch: 5, loss: 2.204
# Final loss 2.204
# protein number 168, length 266
# epoch: 1, loss: 1.673
# epoch: 2, loss: 1.850
# epoch: 3, loss: 1.666
# epoch: 4, loss: 1.660
# epoch: 5, loss: 1.653
# Final loss 1.653
# protein number 169, length 405
# epoch: 1, loss: 1.602
# epoch: 2, loss: 1.583
# epoch: 3, loss: 1.556
# epoch: 4, loss: 1.518
# epoch: 5, loss: 1.549
# Final loss 1.549
# protein number 170, length 128
# epoch: 1, loss: 2.360
# epoch: 2, loss: 2.338
# epoch: 3, loss: 2.246
# epoch: 4, loss: 2.275
# epoch: 5, loss: 2.235
# Final loss 2.235
# protein number 171, length 143
# epoch: 1, loss: 1.614
# epoch: 2, loss: 1.613
# epoch: 3, loss: 1.775
# epoch: 4, loss: 1.761
# epoch: 5, loss: 1.774
# Final loss 1.774
# protein number 172, length 328
# epoch: 1, loss: 1.638
# epoch: 2, loss: 1.600
# epoch: 3, loss: 1.587
# epoch: 4, loss: 1.675
# epoch: 5, loss: 1.656
# Final loss 1.656
# protein number 173, length 188
# epoch: 1, loss: 1.953
# epoch: 2, loss: 1.878
# epoch: 3, loss: 2.032
# epoch: 4, loss: 1.907
# epoch: 5, loss: 1.844
# Final loss 1.844
# protein number 174, length 264
# epoch: 1, loss: 1.787
# epoch: 2, loss: 1.683
# epoch: 3, loss: 1.688
# epoch: 4, loss: 1.676
# epoch: 5, loss: 1.676
# Final loss 1.676
# protein number 175, length 158
# epoch: 1, loss: 2.231
# epoch: 2, loss: 2.161
# epoch: 3, loss: 1.950
# epoch: 4, loss: 2.182
# epoch: 5, loss: 1.943
# Final loss 1.943
# protein number 176, length 250
# epoch: 1, loss: 2.056
# epoch: 2, loss: 2.011
# epoch: 3, loss: 1.925
# epoch: 4, loss: 2.072
# epoch: 5, loss: 2.038
# Final loss 2.038
# protein number 177, length 143
# epoch: 1, loss: 2.047
# epoch: 2, loss: 2.000
# epoch: 3, loss: 1.610
# epoch: 4, loss: 1.618
# epoch: 5, loss: 1.766
# Final loss 1.766
# protein number 178, length 112
# epoch: 1, loss: 1.423
# epoch: 2, loss: 1.662
# epoch: 3, loss: 1.599
# epoch: 4, loss: 1.880
# epoch: 5, loss: 1.904
# Final loss 1.904
# protein number 179, length 126
# epoch: 1, loss: 2.226
# epoch: 2, loss: 2.236
# epoch: 3, loss: 2.162
# epoch: 4, loss: 2.224
# epoch: 5, loss: 2.232
# Final loss 2.232
# protein number 180, length 434
# epoch: 1, loss: 1.563
# epoch: 2, loss: 1.517
# epoch: 3, loss: 1.511
# epoch: 4, loss: 1.516
# epoch: 5, loss: 1.562
# Final loss 1.562
# protein number 181, length 187
# epoch: 1, loss: 2.196
# epoch: 2, loss: 1.964
# epoch: 3, loss: 2.176
# epoch: 4, loss: 2.164
# epoch: 5, loss: 2.001
# Final loss 2.001
# protein number 182, length 236
# epoch: 1, loss: 1.803
# epoch: 2, loss: 1.796
# epoch: 3, loss: 1.811
# epoch: 4, loss: 1.773
# epoch: 5, loss: 1.884
# Final loss 1.884
# protein number 183, length 282
# epoch: 1, loss: 1.952
# epoch: 2, loss: 1.954
# epoch: 3, loss: 1.855
# epoch: 4, loss: 1.776
# epoch: 5, loss: 1.844
# Final loss 1.844
# protein number 184, length 66
# epoch: 1, loss: 0.839
# epoch: 2, loss: 0.821
# epoch: 3, loss: 0.810
# epoch: 4, loss: 1.015
# epoch: 5, loss: 0.963
# Final loss 0.963
# protein number 185, length 220
# epoch: 1, loss: 1.958
# epoch: 2, loss: 2.067
# epoch: 3, loss: 1.901
# epoch: 4, loss: 2.068
# epoch: 5, loss: 2.067
# Final loss 2.067
# protein number 186, length 143
# epoch: 1, loss: 2.052
# epoch: 2, loss: 2.067
# epoch: 3, loss: 1.620
# epoch: 4, loss: 2.030
# epoch: 5, loss: 1.785
# Final loss 1.785
# protein number 187, length 143
# epoch: 1, loss: 1.782
# epoch: 2, loss: 1.747
# epoch: 3, loss: 1.610
# epoch: 4, loss: 1.600
# epoch: 5, loss: 1.741
# Final loss 1.741
# protein number 188, length 66
# epoch: 1, loss: 0.816
# epoch: 2, loss: 0.797
# epoch: 3, loss: 0.797
# epoch: 4, loss: 0.786
# epoch: 5, loss: 0.767
# Final loss 0.767
# protein number 189, length 112
# epoch: 1, loss: 1.642
# epoch: 2, loss: 1.939
# epoch: 3, loss: 1.405
# epoch: 4, loss: 1.946
# epoch: 5, loss: 1.954
# Final loss 1.954
# protein number 190, length 174
# epoch: 1, loss: 1.703
# epoch: 2, loss: 1.808
# epoch: 3, loss: 1.804
# epoch: 4, loss: 1.821
# epoch: 5, loss: 1.679
# Final loss 1.679
# protein number 191, length 143
# epoch: 1, loss: 1.580
# epoch: 2, loss: 1.571
# epoch: 3, loss: 1.975
# epoch: 4, loss: 1.734
# epoch: 5, loss: 1.950
# Final loss 1.950
# protein number 192, length 296
# epoch: 1, loss: 1.632
# epoch: 2, loss: 1.663
# epoch: 3, loss: 1.614
# epoch: 4, loss: 1.666
# epoch: 5, loss: 1.666
# Final loss 1.666
# protein number 193, length 81
# epoch: 1, loss: 1.151
# epoch: 2, loss: 1.370
# epoch: 3, loss: 1.352
# epoch: 4, loss: 1.382
# epoch: 5, loss: 1.375
# Final loss 1.375
# protein number 194, length 35
# epoch: 1, loss: 0.181
# epoch: 2, loss: 0.356
# epoch: 3, loss: 0.176
# epoch: 4, loss: 0.175
# epoch: 5, loss: 0.174
# Final loss 0.174
# protein number 195, length 126
# epoch: 1, loss: 2.299
# epoch: 2, loss: 2.267
# epoch: 3, loss: 2.266
# epoch: 4, loss: 2.234
# epoch: 5, loss: 2.150
# Final loss 2.150
# protein number 196, length 249
# epoch: 1, loss: 1.871
# epoch: 2, loss: 1.867
# epoch: 3, loss: 1.979
# epoch: 4, loss: 1.972
# epoch: 5, loss: 1.976
# Final loss 1.976
# protein number 197, length 296
# epoch: 1, loss: 1.724
# epoch: 2, loss: 1.781
# epoch: 3, loss: 1.765
# epoch: 4, loss: 1.700
# epoch: 5, loss: 1.771
# Final loss 1.771
# protein number 198, length 81
# epoch: 1, loss: 1.138
# epoch: 2, loss: 1.099
# epoch: 3, loss: 1.388
# epoch: 4, loss: 1.393
# epoch: 5, loss: 1.387
# Final loss 1.387
# protein number 199, length 451
# epoch: 1, loss: 1.497
# epoch: 2, loss: 1.480
# epoch: 3, loss: 1.432
# epoch: 4, loss: 1.468
# epoch: 5, loss: 1.430
# Final loss 1.430
# protein number 200, length 35
# epoch: 1, loss: 0.220
# epoch: 2, loss: 0.201
# epoch: 3, loss: 0.380
# epoch: 4, loss: 0.192
# epoch: 5, loss: 0.188
# Final loss 0.188
# protein number 201, length 50
# epoch: 1, loss: 0.792
# epoch: 2, loss: 0.787
# epoch: 3, loss: 0.723
# epoch: 4, loss: 0.515
# epoch: 5, loss: 0.510
# Final loss 0.510
# protein number 202, length 112
# epoch: 1, loss: 1.517
# epoch: 2, loss: 1.708
# epoch: 3, loss: 1.709
# epoch: 4, loss: 1.462
# epoch: 5, loss: 1.695
# Final loss 1.695
# protein number 203, length 97
# epoch: 1, loss: 1.189
# epoch: 2, loss: 1.126
# epoch: 3, loss: 1.577
# epoch: 4, loss: 1.187
# epoch: 5, loss: 1.190
# Final loss 1.190
# protein number 204, length 373
# epoch: 1, loss: 1.794
# epoch: 2, loss: 1.716
# epoch: 3, loss: 1.686
# epoch: 4, loss: 1.779
# epoch: 5, loss: 1.752
# Final loss 1.752
# protein number 205, length 158
# epoch: 1, loss: 2.257
# epoch: 2, loss: 2.198
# epoch: 3, loss: 2.218
# epoch: 4, loss: 2.213
# epoch: 5, loss: 2.185
# Final loss 2.185
# protein number 206, length 50
# epoch: 1, loss: 0.821
# epoch: 2, loss: 1.207
# epoch: 3, loss: 0.520
# epoch: 4, loss: 1.244
# epoch: 5, loss: 1.227
# Final loss 1.227
# protein number 207, length 189
# epoch: 1, loss: 2.157
# epoch: 2, loss: 2.128
# epoch: 3, loss: 2.173
# epoch: 4, loss: 2.120
# epoch: 5, loss: 2.151
# Final loss 2.151
# protein number 208, length 187
# epoch: 1, loss: 2.163
# epoch: 2, loss: 2.013
# epoch: 3, loss: 2.190
# epoch: 4, loss: 2.157
# epoch: 5, loss: 1.997
# Final loss 1.997
# protein number 209, length 143
# epoch: 1, loss: 2.015
# epoch: 2, loss: 1.790
# epoch: 3, loss: 1.793
# epoch: 4, loss: 1.641
# epoch: 5, loss: 1.641
# Final loss 1.641
# protein number 210, length 97
# epoch: 1, loss: 1.221
# epoch: 2, loss: 1.227
# epoch: 3, loss: 1.174
# epoch: 4, loss: 1.158
# epoch: 5, loss: 1.222
# Final loss 1.222
# protein number 211, length 775
# epoch: 1, loss: 1.165
# epoch: 2, loss: 1.155
# epoch: 3, loss: 1.211
# epoch: 4, loss: 1.193
# epoch: 5, loss: 1.164
# Final loss 1.164
# protein number 212, length 141
# epoch: 1, loss: 1.814
# epoch: 2, loss: 1.840
# epoch: 3, loss: 1.789
# epoch: 4, loss: 1.806
# epoch: 5, loss: 1.628
# Final loss 1.628
# protein number 213, length 220
# epoch: 1, loss: 2.087
# epoch: 2, loss: 2.114
# epoch: 3, loss: 2.115
# epoch: 4, loss: 1.954
# epoch: 5, loss: 2.032
# Final loss 2.032
# protein number 214, length 219
# epoch: 1, loss: 1.964
# epoch: 2, loss: 1.957
# epoch: 3, loss: 1.950
# epoch: 4, loss: 1.902
# epoch: 5, loss: 1.966
# Final loss 1.966
# protein number 215, length 282
# epoch: 1, loss: 1.936
# epoch: 2, loss: 2.019
# epoch: 3, loss: 2.018
# epoch: 4, loss: 1.903
# epoch: 5, loss: 1.999
# Final loss 1.999
# protein number 216, length 158
# epoch: 1, loss: 2.298
# epoch: 2, loss: 2.253
# epoch: 3, loss: 2.260
# epoch: 4, loss: 2.224
# epoch: 5, loss: 2.232
# Final loss 2.232
# protein number 217, length 81
# epoch: 1, loss: 1.090
# epoch: 2, loss: 1.079
# epoch: 3, loss: 1.801
# epoch: 4, loss: 1.350
# epoch: 5, loss: 1.072
# Final loss 1.072
# protein number 218, length 143
# epoch: 1, loss: 1.800
# epoch: 2, loss: 1.795
# epoch: 3, loss: 2.002
# epoch: 4, loss: 1.754
# epoch: 5, loss: 1.786
# Final loss 1.786
# protein number 219, length 97
# epoch: 1, loss: 1.252
# epoch: 2, loss: 1.240
# epoch: 3, loss: 1.188
# epoch: 4, loss: 1.228
# epoch: 5, loss: 1.197
# Final loss 1.197
# protein number 220, length 250
# epoch: 1, loss: 1.896
# epoch: 2, loss: 1.893
# epoch: 3, loss: 1.883
# epoch: 4, loss: 1.988
# epoch: 5, loss: 2.001
# Final loss 2.001
# protein number 221, length 35
# epoch: 1, loss: 0.370
# epoch: 2, loss: 0.353
# epoch: 3, loss: 0.178
# epoch: 4, loss: 0.177
# epoch: 5, loss: 0.176
# Final loss 0.176
# protein number 222, length 111
# epoch: 1, loss: 1.556
# epoch: 2, loss: 1.575
# epoch: 3, loss: 1.569
# epoch: 4, loss: 1.818
# epoch: 5, loss: 1.823
# Final loss 1.823
# protein number 223, length 50
# epoch: 1, loss: 0.694
# epoch: 2, loss: 0.756
# epoch: 3, loss: 0.484
# epoch: 4, loss: 0.765
# epoch: 5, loss: 1.186
# Final loss 1.186
# protein number 224, length 205
# epoch: 1, loss: 1.747
# epoch: 2, loss: 1.742
# epoch: 3, loss: 1.888
# epoch: 4, loss: 1.741
# epoch: 5, loss: 1.893
# Final loss 1.893
# protein number 225, length 97
# epoch: 1, loss: 1.223
# epoch: 2, loss: 1.233
# epoch: 3, loss: 1.193
# epoch: 4, loss: 1.182
# epoch: 5, loss: 1.218
# Final loss 1.218
# protein number 226, length 359
# epoch: 1, loss: 1.628
# epoch: 2, loss: 1.600
# epoch: 3, loss: 1.585
# epoch: 4, loss: 1.600
# epoch: 5, loss: 1.653
# Final loss 1.653
# protein number 227, length 218
# epoch: 1, loss: 2.062
# epoch: 2, loss: 2.074
# epoch: 3, loss: 2.037
# epoch: 4, loss: 1.911
# epoch: 5, loss: 2.063
# Final loss 2.063
# protein number 228, length 35
# epoch: 1, loss: 0.200
# epoch: 2, loss: 0.188
# epoch: 3, loss: 0.375
# epoch: 4, loss: 0.184
# epoch: 5, loss: 0.182
# Final loss 0.182
# protein number 229, length 220
# epoch: 1, loss: 2.027
# epoch: 2, loss: 2.111
# epoch: 3, loss: 1.961
# epoch: 4, loss: 2.105
# epoch: 5, loss: 2.112
# Final loss 2.112
# protein number 230, length 50
# epoch: 1, loss: 0.763
# epoch: 2, loss: 0.748
# epoch: 3, loss: 1.139
# epoch: 4, loss: 0.689
# epoch: 5, loss: 0.658
# Final loss 0.658
# protein number 231, length 97
# epoch: 1, loss: 1.187
# epoch: 2, loss: 1.390
# epoch: 3, loss: 1.201
# epoch: 4, loss: 1.152
# epoch: 5, loss: 1.155
# Final loss 1.155
# protein number 232, length 97
# epoch: 1, loss: 1.168
# epoch: 2, loss: 1.180
# epoch: 3, loss: 1.179
# epoch: 4, loss: 1.177
# epoch: 5, loss: 1.179
# Final loss 1.179
# protein number 233, length 404
# epoch: 1, loss: 1.651
# epoch: 2, loss: 1.668
# epoch: 3, loss: 1.660
# epoch: 4, loss: 1.661
# epoch: 5, loss: 1.659
# Final loss 1.659
# protein number 234, length 174
# epoch: 1, loss: 1.835
# epoch: 2, loss: 2.023
# epoch: 3, loss: 1.809
# epoch: 4, loss: 1.800
# epoch: 5, loss: 1.781
# Final loss 1.781
# protein number 235, length 189
# epoch: 1, loss: 2.182
# epoch: 2, loss: 1.828
# epoch: 3, loss: 2.105
# epoch: 4, loss: 1.930
# epoch: 5, loss: 2.119
# Final loss 2.119
# protein number 236, length 373
# epoch: 1, loss: 1.660
# epoch: 2, loss: 1.636
# epoch: 3, loss: 1.711
# epoch: 4, loss: 1.703
# epoch: 5, loss: 1.704
# Final loss 1.704
# protein number 237, length 128
# epoch: 1, loss: 2.317
# epoch: 2, loss: 2.259
# epoch: 3, loss: 2.339
# epoch: 4, loss: 2.323
# epoch: 5, loss: 2.322
# Final loss 2.322
# protein number 238, length 143
# epoch: 1, loss: 1.709
# epoch: 2, loss: 1.566
# epoch: 3, loss: 1.951
# epoch: 4, loss: 1.723
# epoch: 5, loss: 1.973
# Final loss 1.973
# protein number 239, length 216
# epoch: 1, loss: 1.797
# epoch: 2, loss: 1.807
# epoch: 3, loss: 1.951
# epoch: 4, loss: 1.790
# epoch: 5, loss: 1.780
# Final loss 1.780
# protein number 240, length 234
# epoch: 1, loss: 1.673
# epoch: 2, loss: 1.671
# epoch: 3, loss: 1.785
# epoch: 4, loss: 1.805
# epoch: 5, loss: 1.655
# Final loss 1.655
# protein number 241, length 158
# epoch: 1, loss: 2.202
# epoch: 2, loss: 2.103
# epoch: 3, loss: 2.147
# epoch: 4, loss: 2.105
# epoch: 5, loss: 1.899
# Final loss 1.899
# protein number 242, length 328
# epoch: 1, loss: 1.676
# epoch: 2, loss: 1.589
# epoch: 3, loss: 1.578
# epoch: 4, loss: 1.668
# epoch: 5, loss: 1.573
# Final loss 1.573
# protein number 243, length 205
# epoch: 1, loss: 1.876
# epoch: 2, loss: 1.860
# epoch: 3, loss: 1.682
# epoch: 4, loss: 1.811
# epoch: 5, loss: 1.822
# Final loss 1.822
# protein number 244, length 328
# epoch: 1, loss: 1.577
# epoch: 2, loss: 1.641
# epoch: 3, loss: 1.568
# epoch: 4, loss: 1.562
# epoch: 5, loss: 1.640
# Final loss 1.640
# protein number 245, length 311
# epoch: 1, loss: 1.766
# epoch: 2, loss: 1.755
# epoch: 3, loss: 1.746
# epoch: 4, loss: 1.750
# epoch: 5, loss: 1.743
# Final loss 1.743
# protein number 246, length 313
# epoch: 1, loss: 1.868
# epoch: 2, loss: 1.841
# epoch: 3, loss: 1.725
# epoch: 4, loss: 1.807
# epoch: 5, loss: 1.710
# Final loss 1.710
# protein number 247, length 97
# epoch: 1, loss: 1.211
# epoch: 2, loss: 1.183
# epoch: 3, loss: 1.136
# epoch: 4, loss: 1.147
# epoch: 5, loss: 1.101
# Final loss 1.101
# protein number 248, length 189
# epoch: 1, loss: 2.235
# epoch: 2, loss: 2.203
# epoch: 3, loss: 2.210
# epoch: 4, loss: 2.213
# epoch: 5, loss: 2.198
# Final loss 2.198
# protein number 249, length 313
# epoch: 1, loss: 1.865
# epoch: 2, loss: 1.844
# epoch: 3, loss: 1.832
# epoch: 4, loss: 1.692
# epoch: 5, loss: 1.865
# Final loss 1.865
# protein number 250, length 174
# epoch: 1, loss: 1.648
# epoch: 2, loss: 1.619
# epoch: 3, loss: 1.941
# epoch: 4, loss: 1.890
# epoch: 5, loss: 1.703
# Final loss 1.703
# protein number 251, length 128
# epoch: 1, loss: 2.237
# epoch: 2, loss: 2.144
# epoch: 3, loss: 2.155
# epoch: 4, loss: 2.176
# epoch: 5, loss: 2.072
# Final loss 2.072
# protein number 252, length 405
# epoch: 1, loss: 1.629
# epoch: 2, loss: 1.597
# epoch: 3, loss: 1.650
# epoch: 4, loss: 1.637
# epoch: 5, loss: 1.630
# Final loss 1.630
# protein number 253, length 388
# epoch: 1, loss: 1.649
# epoch: 2, loss: 1.637
# epoch: 3, loss: 1.629
# epoch: 4, loss: 1.625
# epoch: 5, loss: 1.677
# Final loss 1.677
# protein number 254, length 112
# epoch: 1, loss: 2.016
# epoch: 2, loss: 1.657
# epoch: 3, loss: 1.425
# epoch: 4, loss: 1.612
# epoch: 5, loss: 1.958
# Final loss 1.958
# protein number 255, length 35
# epoch: 1, loss: 0.184
# epoch: 2, loss: 0.180
# epoch: 3, loss: 0.176
# epoch: 4, loss: 0.176
# epoch: 5, loss: 0.175
# Final loss 0.175
# protein number 256, length 205
# epoch: 1, loss: 1.738
# epoch: 2, loss: 1.727
# epoch: 3, loss: 1.716
# epoch: 4, loss: 1.856
# epoch: 5, loss: 1.844
# Final loss 1.844
# protein number 257, length 174
# epoch: 1, loss: 1.650
# epoch: 2, loss: 1.638
# epoch: 3, loss: 1.945
# epoch: 4, loss: 1.778
# epoch: 5, loss: 1.928
# Final loss 1.928
# protein number 258, length 128
# epoch: 1, loss: 2.183
# epoch: 2, loss: 2.193
# epoch: 3, loss: 2.216
# epoch: 4, loss: 2.151
# epoch: 5, loss: 2.157
# Final loss 2.157
# protein number 259, length 66
# epoch: 1, loss: 1.039
# epoch: 2, loss: 0.830
# epoch: 3, loss: 0.777
# epoch: 4, loss: 0.824
# epoch: 5, loss: 0.821
# Final loss 0.821
# protein number 260, length 158
# epoch: 1, loss: 2.187
# epoch: 2, loss: 1.936
# epoch: 3, loss: 2.150
# epoch: 4, loss: 2.160
# epoch: 5, loss: 2.160
# Final loss 2.160
# protein number 261, length 173
# epoch: 1, loss: 1.749
# epoch: 2, loss: 1.721
# epoch: 3, loss: 1.735
# epoch: 4, loss: 1.714
# epoch: 5, loss: 1.727
# Final loss 1.727
# protein number 262, length 236
# epoch: 1, loss: 1.646
# epoch: 2, loss: 1.632
# epoch: 3, loss: 1.624
# epoch: 4, loss: 1.730
# epoch: 5, loss: 1.746
# Final loss 1.746
# protein number 263, length 66
# epoch: 1, loss: 0.786
# epoch: 2, loss: 0.762
# epoch: 3, loss: 0.752
# epoch: 4, loss: 0.792
# epoch: 5, loss: 0.764
# Final loss 0.764
# protein number 264, length 729
# epoch: 1, loss: 1.335
# epoch: 2, loss: 1.338
# epoch: 3, loss: 1.305
# epoch: 4, loss: 1.313
# epoch: 5, loss: 1.299
# Final loss 1.299
# protein number 265, length 158
# epoch: 1, loss: 2.276
# epoch: 2, loss: 2.189
# epoch: 3, loss: 1.737
# epoch: 4, loss: 1.933
# epoch: 5, loss: 2.151
# Final loss 2.151
# protein number 266, length 158
# epoch: 1, loss: 2.227
# epoch: 2, loss: 2.188
# epoch: 3, loss: 1.975
# epoch: 4, loss: 1.972
# epoch: 5, loss: 2.224
# Final loss 2.224
# protein number 267, length 342
# epoch: 1, loss: 1.828
# epoch: 2, loss: 1.728
# epoch: 3, loss: 1.805
# epoch: 4, loss: 1.729
# epoch: 5, loss: 1.741
# Final loss 1.741
# protein number 268, length 372
# epoch: 1, loss: 1.607
# epoch: 2, loss: 1.666
# epoch: 3, loss: 1.749
# epoch: 4, loss: 1.660
# epoch: 5, loss: 1.612
# Final loss 1.612
# protein number 269, length 680
# epoch: 1, loss: 1.226
# epoch: 2, loss: 1.209
# epoch: 3, loss: 1.227
# epoch: 4, loss: 1.216
# epoch: 5, loss: 1.218
# Final loss 1.218
# protein number 270, length 128
# epoch: 1, loss: 2.406
# epoch: 2, loss: 2.267
# epoch: 3, loss: 2.174
# epoch: 4, loss: 2.147
# epoch: 5, loss: 2.254
# Final loss 2.254
# protein number 271, length 112
# epoch: 1, loss: 1.616
# epoch: 2, loss: 1.639
# epoch: 3, loss: 1.944
# epoch: 4, loss: 1.958
# epoch: 5, loss: 1.415
# Final loss 1.415
# protein number 272, length 343
# epoch: 1, loss: 1.643
# epoch: 2, loss: 1.706
# epoch: 3, loss: 1.769
# epoch: 4, loss: 1.759
# epoch: 5, loss: 1.696
# Final loss 1.696
# protein number 273, length 35
# epoch: 1, loss: 0.194
# epoch: 2, loss: 0.192
# epoch: 3, loss: 0.188
# epoch: 4, loss: 0.184
# epoch: 5, loss: 0.182
# Final loss 0.182
# protein number 274, length 112
# epoch: 1, loss: 1.706
# epoch: 2, loss: 1.929
# epoch: 3, loss: 1.965
# epoch: 4, loss: 1.647
# epoch: 5, loss: 1.414
# Final loss 1.414
# protein number 275, length 482
# epoch: 1, loss: 1.438
# epoch: 2, loss: 1.421
# epoch: 3, loss: 1.394
# epoch: 4, loss: 1.392
# epoch: 5, loss: 1.394
# Final loss 1.394
# protein number 276, length 218
# epoch: 1, loss: 2.106
# epoch: 2, loss: 2.032
# epoch: 3, loss: 1.782
# epoch: 4, loss: 1.855
# epoch: 5, loss: 2.043
# Final loss 2.043
# protein number 277, length 97
# epoch: 1, loss: 1.206
# epoch: 2, loss: 1.192
# epoch: 3, loss: 1.186
# epoch: 4, loss: 1.172
# epoch: 5, loss: 1.167
# Final loss 1.167
# protein number 278, length 498
# epoch: 1, loss: 1.590
# epoch: 2, loss: 1.548
# epoch: 3, loss: 1.543
# epoch: 4, loss: 1.595
# epoch: 5, loss: 1.536
# Final loss 1.536
# protein number 279, length 219
# epoch: 1, loss: 2.149
# epoch: 2, loss: 2.112
# epoch: 3, loss: 2.038
# epoch: 4, loss: 2.034
# epoch: 5, loss: 2.053
# Final loss 2.053
# protein number 280, length 480
# epoch: 1, loss: 1.555
# epoch: 2, loss: 1.526
# epoch: 3, loss: 1.528
# epoch: 4, loss: 1.533
# epoch: 5, loss: 1.519
# Final loss 1.519
# protein number 281, length 355
# epoch: 1, loss: 1.591
# epoch: 2, loss: 1.573
# epoch: 3, loss: 1.563
# epoch: 4, loss: 1.557
# epoch: 5, loss: 1.564
# Final loss 1.564
# protein number 282, length 174
# epoch: 1, loss: 1.821
# epoch: 2, loss: 1.976
# epoch: 3, loss: 1.666
# epoch: 4, loss: 1.798
# epoch: 5, loss: 1.659
# Final loss 1.659
# protein number 283, length 97
# epoch: 1, loss: 1.155
# epoch: 2, loss: 1.154
# epoch: 3, loss: 1.126
# epoch: 4, loss: 1.120
# epoch: 5, loss: 1.122
# Final loss 1.122
# protein number 284, length 97
# epoch: 1, loss: 1.205
# epoch: 2, loss: 1.163
# epoch: 3, loss: 1.416
# epoch: 4, loss: 1.180
# epoch: 5, loss: 1.229
# Final loss 1.229
# protein number 285, length 35
# epoch: 1, loss: 0.186
# epoch: 2, loss: 0.182
# epoch: 3, loss: 0.351
# epoch: 4, loss: 0.178
# epoch: 5, loss: 0.178
# Final loss 0.178
# protein number 286, length 157
# epoch: 1, loss: 2.178
# epoch: 2, loss: 2.217
# epoch: 3, loss: 2.142
# epoch: 4, loss: 1.932
# epoch: 5, loss: 2.145
# Final loss 2.145
# protein number 287, length 403
# epoch: 1, loss: 1.578
# epoch: 2, loss: 1.564
# epoch: 3, loss: 1.603
# epoch: 4, loss: 1.606
# epoch: 5, loss: 1.544
# Final loss 1.544
# protein number 288, length 66
# epoch: 1, loss: 0.828
# epoch: 2, loss: 0.802
# epoch: 3, loss: 0.786
# epoch: 4, loss: 0.734
# epoch: 5, loss: 0.994
# Final loss 0.994
# protein number 289, length 35
# epoch: 1, loss: 0.340
# epoch: 2, loss: 0.332
# epoch: 3, loss: 0.171
# epoch: 4, loss: 0.170
# epoch: 5, loss: 0.170
# Final loss 0.170
# protein number 290, length 35
# epoch: 1, loss: 0.179
# epoch: 2, loss: 0.179
# epoch: 3, loss: 0.178
# epoch: 4, loss: 0.178
# epoch: 5, loss: 0.178
# Final loss 0.178
# protein number 291, length 128
# epoch: 1, loss: 2.256
# epoch: 2, loss: 2.257
# epoch: 3, loss: 2.171
# epoch: 4, loss: 2.234
# epoch: 5, loss: 2.231
# Final loss 2.231
# protein number 292, length 97
# epoch: 1, loss: 1.221
# epoch: 2, loss: 1.203
# epoch: 3, loss: 1.169
# epoch: 4, loss: 1.191
# epoch: 5, loss: 1.176
# Final loss 1.176
# protein number 293, length 205
# epoch: 1, loss: 1.768
# epoch: 2, loss: 1.599
# epoch: 3, loss: 1.704
# epoch: 4, loss: 1.717
# epoch: 5, loss: 1.725
# Final loss 1.725
# protein number 294, length 311
# epoch: 1, loss: 1.760
# epoch: 2, loss: 1.792
# epoch: 3, loss: 1.799
# epoch: 4, loss: 1.799
# epoch: 5, loss: 1.868
# Final loss 1.868
# protein number 295, length 374
# epoch: 1, loss: 1.803
# epoch: 2, loss: 1.782
# epoch: 3, loss: 1.678
# epoch: 4, loss: 1.793
# epoch: 5, loss: 1.704
# Final loss 1.704
# protein number 296, length 97
# epoch: 1, loss: 1.245
# epoch: 2, loss: 1.184
# epoch: 3, loss: 1.171
# epoch: 4, loss: 1.177
# epoch: 5, loss: 1.210
# Final loss 1.210
# protein number 297, length 337
# epoch: 1, loss: 1.747
# epoch: 2, loss: 1.789
# epoch: 3, loss: 1.785
# epoch: 4, loss: 1.613
# epoch: 5, loss: 1.610
# Final loss 1.610
# protein number 298, length 174
# epoch: 1, loss: 1.714
# epoch: 2, loss: 1.814
# epoch: 3, loss: 1.802
# epoch: 4, loss: 1.670
# epoch: 5, loss: 1.657
# Final loss 1.657
# protein number 299, length 173
# epoch: 1, loss: 1.845
# epoch: 2, loss: 1.841
# epoch: 3, loss: 1.840
# epoch: 4, loss: 1.707
# epoch: 5, loss: 1.704
# Final loss 1.704
# protein number 300, length 357
# epoch: 1, loss: 1.642
# epoch: 2, loss: 1.690
# epoch: 3, loss: 1.612
# epoch: 4, loss: 1.625
# epoch: 5, loss: 1.671
# Final loss 1.671
# protein number 301, length 205
# epoch: 1, loss: 1.723
# epoch: 2, loss: 1.859
# epoch: 3, loss: 1.702
# epoch: 4, loss: 1.691
# epoch: 5, loss: 1.842
# Final loss 1.842
# protein number 302, length 174
# epoch: 1, loss: 1.845
# epoch: 2, loss: 1.837
# epoch: 3, loss: 2.021
# epoch: 4, loss: 2.004
# epoch: 5, loss: 1.822
# Final loss 1.822
# protein number 303, length 236
# epoch: 1, loss: 1.803
# epoch: 2, loss: 1.664
# epoch: 3, loss: 1.878
# epoch: 4, loss: 1.780
# epoch: 5, loss: 1.653
# Final loss 1.653
# protein number 304, length 158
# epoch: 1, loss: 2.161
# epoch: 2, loss: 2.137
# epoch: 3, loss: 2.175
# epoch: 4, loss: 2.175
# ...
# epoch: 4, loss: 0.994
# epoch: 5, loss: 1.002
# Final loss 1.002
# protein number 531, length 128
# epoch: 1, loss: 2.504
# epoch: 2, loss: 2.413
# epoch: 3, loss: 2.325
# epoch: 4, loss: 2.280
# epoch: 5, loss: 2.211
# Final loss 2.211
# protein number 532, length 112
# epoch: 1, loss: 1.658
# epoch: 2, loss: 1.936
# epoch: 3, loss: 1.671
# epoch: 4, loss: 1.989
# epoch: 5, loss: 1.924
# Final loss 1.924
# protein number 533, length 220
# epoch: 1, loss: 2.188
# epoch: 2, loss: 2.165
# epoch: 3, loss: 2.157
# epoch: 4, loss: 2.139
# epoch: 5, loss: 1.992
# Final loss 1.992
# protein number 534, length 81
# epoch: 1, loss: 1.781
# epoch: 2, loss: 1.307
# epoch: 3, loss: 1.046
# epoch: 4, loss: 1.338
# epoch: 5, loss: 1.698
# Final loss 1.698
# protein number 535, length 158
# epoch: 1, loss: 2.162
# epoch: 2, loss: 2.097
# epoch: 3, loss: 2.137
# epoch: 4, loss: 2.137
# epoch: 5, loss: 2.132
# Final loss 2.132
# protein number 536, length 65
# epoch: 1, loss: 1.011
# epoch: 2, loss: 0.805
# epoch: 3, loss: 0.808
# epoch: 4, loss: 0.771
# epoch: 5, loss: 0.754
# Final loss 0.754
# protein number 537, length 112
# epoch: 1, loss: 1.409
# epoch: 2, loss: 1.402
# epoch: 3, loss: 1.391
# epoch: 4, loss: 1.389
# epoch: 5, loss: 1.603
# Final loss 1.603
# protein number 538, length 296
# epoch: 1, loss: 1.683
# epoch: 2, loss: 1.662
# epoch: 3, loss: 1.730
# epoch: 4, loss: 1.670
# epoch: 5, loss: 1.728
# Final loss 1.728
# protein number 539, length 143
# epoch: 1, loss: 1.839
# epoch: 2, loss: 2.037
# epoch: 3, loss: 1.774
# epoch: 4, loss: 1.623
# epoch: 5, loss: 1.621
# Final loss 1.621
# protein number 540, length 297
# epoch: 1, loss: 1.712
# epoch: 2, loss: 1.683
# epoch: 3, loss: 1.619
# epoch: 4, loss: 1.675
# epoch: 5, loss: 1.668
# Final loss 1.668
# protein number 541, length 173
# epoch: 1, loss: 1.814
# epoch: 2, loss: 1.652
# epoch: 3, loss: 1.759
# epoch: 4, loss: 1.950
# epoch: 5, loss: 1.985
# Final loss 1.985
# protein number 542, length 97
# epoch: 1, loss: 1.141
# epoch: 2, loss: 1.186
# epoch: 3, loss: 1.179
# epoch: 4, loss: 1.121
# epoch: 5, loss: 1.120
# Final loss 1.120
# protein number 543, length 189
# epoch: 1, loss: 2.151
# epoch: 2, loss: 2.195
# epoch: 3, loss: 2.147
# epoch: 4, loss: 2.146
# epoch: 5, loss: 1.954
# Final loss 1.954
# protein number 544, length 236
# epoch: 1, loss: 1.692
# epoch: 2, loss: 1.671
# epoch: 3, loss: 1.667
# epoch: 4, loss: 1.779
# epoch: 5, loss: 1.666
# Final loss 1.666
# protein number 545, length 143
# epoch: 1, loss: 1.578
# epoch: 2, loss: 1.555
# epoch: 3, loss: 1.546
# epoch: 4, loss: 1.944
# epoch: 5, loss: 1.703
# Final loss 1.703
# protein number 546, length 174
# epoch: 1, loss: 1.721
# epoch: 2, loss: 2.002
# epoch: 3, loss: 1.819
# epoch: 4, loss: 1.996
# epoch: 5, loss: 1.701
# Final loss 1.701
# protein number 547, length 111
# epoch: 1, loss: 1.461
# epoch: 2, loss: 1.983
# epoch: 3, loss: 1.660
# epoch: 4, loss: 1.659
# epoch: 5, loss: 1.436
# Final loss 1.436
# protein number 548, length 390
# epoch: 1, loss: 1.607
# epoch: 2, loss: 1.570
# epoch: 3, loss: 1.566
# epoch: 4, loss: 1.573
# epoch: 5, loss: 1.514
# Final loss 1.514
# protein number 549, length 448
# epoch: 1, loss: 1.706
# epoch: 2, loss: 1.687
# epoch: 3, loss: 1.693
# epoch: 4, loss: 1.687
# epoch: 5, loss: 1.676
# Final loss 1.676
# protein number 550, length 282
# epoch: 1, loss: 1.968
# epoch: 2, loss: 1.860
# epoch: 3, loss: 1.959
# epoch: 4, loss: 1.947
# epoch: 5, loss: 1.778
# Final loss 1.778
# protein number 551, length 127
# epoch: 1, loss: 2.218
# epoch: 2, loss: 2.210
# epoch: 3, loss: 2.201
# epoch: 4, loss: 2.151
# epoch: 5, loss: 1.872
# Final loss 1.872
# protein number 552, length 35
# epoch: 1, loss: 0.189
# epoch: 2, loss: 0.186
# epoch: 3, loss: 0.183
# epoch: 4, loss: 0.359
# epoch: 5, loss: 0.181
# Final loss 0.181
# protein number 553, length 205
# epoch: 1, loss: 1.731
# epoch: 2, loss: 1.857
# epoch: 3, loss: 1.862
# epoch: 4, loss: 1.846
# epoch: 5, loss: 1.969
# Final loss 1.969
# protein number 554, length 262
# epoch: 1, loss: 1.817
# epoch: 2, loss: 1.821
# epoch: 3, loss: 1.718
# epoch: 4, loss: 1.722
# epoch: 5, loss: 1.710
# Final loss 1.710
# protein number 555, length 205
# epoch: 1, loss: 1.889
# epoch: 2, loss: 1.747
# epoch: 3, loss: 1.742
# epoch: 4, loss: 1.886
# epoch: 5, loss: 1.876
# Final loss 1.876
# protein number 556, length 575
# epoch: 1, loss: 1.513
# epoch: 2, loss: 1.496
# epoch: 3, loss: 1.475
# epoch: 4, loss: 1.479
# epoch: 5, loss: 1.479
# Final loss 1.479
# protein number 557, length 50
# epoch: 1, loss: 0.561
# epoch: 2, loss: 0.806
# epoch: 3, loss: 0.779
# epoch: 4, loss: 0.698
# epoch: 5, loss: 1.207
# Final loss 1.207
# protein number 558, length 81
# epoch: 1, loss: 1.441
# epoch: 2, loss: 1.406
# epoch: 3, loss: 1.402
# epoch: 4, loss: 1.782
# epoch: 5, loss: 1.766
# Final loss 1.766
# protein number 559, length 97
# epoch: 1, loss: 1.209
# epoch: 2, loss: 1.379
# epoch: 3, loss: 1.206
# epoch: 4, loss: 1.191
# epoch: 5, loss: 1.375
# Final loss 1.375
# protein number 560, length 97
# epoch: 1, loss: 1.237
# epoch: 2, loss: 1.208
# epoch: 3, loss: 1.226
# epoch: 4, loss: 1.247
# epoch: 5, loss: 1.241
# Final loss 1.241
# protein number 561, length 143
# epoch: 1, loss: 1.955
# epoch: 2, loss: 1.996
# epoch: 3, loss: 1.719
# epoch: 4, loss: 1.574
# epoch: 5, loss: 1.969
# Final loss 1.969
# protein number 562, length 158
# epoch: 1, loss: 2.152
# epoch: 2, loss: 2.153
# epoch: 3, loss: 2.145
# epoch: 4, loss: 2.100
# epoch: 5, loss: 2.123
# Final loss 2.123
# protein number 563, length 111
# epoch: 1, loss: 1.664
# epoch: 2, loss: 1.931
# epoch: 3, loss: 1.438
# epoch: 4, loss: 1.437
# epoch: 5, loss: 1.636
# Final loss 1.636
# protein number 564, length 328
# epoch: 1, loss: 1.625
# epoch: 2, loss: 1.692
# epoch: 3, loss: 1.688
# epoch: 4, loss: 1.598
# epoch: 5, loss: 1.586
# Final loss 1.586
# protein number 565, length 66
# epoch: 1, loss: 0.813
# epoch: 2, loss: 0.790
# epoch: 3, loss: 0.784
# epoch: 4, loss: 0.990
# epoch: 5, loss: 0.761
# Final loss 0.761
# protein number 566, length 97
# epoch: 1, loss: 1.460
# epoch: 2, loss: 1.248
# epoch: 3, loss: 1.230
# epoch: 4, loss: 1.245
# epoch: 5, loss: 1.232
# Final loss 1.232
# protein number 567, length 174
# epoch: 1, loss: 2.078
# epoch: 2, loss: 1.714
# epoch: 3, loss: 1.842
# epoch: 4, loss: 1.696
# epoch: 5, loss: 1.704
# Final loss 1.704
# protein number 568, length 35
# epoch: 1, loss: 0.187
# epoch: 2, loss: 0.185
# epoch: 3, loss: 0.183
# epoch: 4, loss: 0.183
# epoch: 5, loss: 0.182
# Final loss 0.182
# protein number 569, length 111
# epoch: 1, loss: 1.631
# epoch: 2, loss: 1.966
# epoch: 3, loss: 1.432
# epoch: 4, loss: 1.417
# epoch: 5, loss: 1.428
# Final loss 1.428
# protein number 570, length 81
# epoch: 1, loss: 1.124
# epoch: 2, loss: 1.884
# epoch: 3, loss: 1.408
# epoch: 4, loss: 1.445
# epoch: 5, loss: 1.120
# Final loss 1.120
# protein number 571, length 35
# epoch: 1, loss: 0.189
# epoch: 2, loss: 0.186
# epoch: 3, loss: 0.185
# epoch: 4, loss: 0.184
# epoch: 5, loss: 0.357
# Final loss 0.357
# protein number 572, length 128
# epoch: 1, loss: 2.153
# epoch: 2, loss: 2.129
# epoch: 3, loss: 2.190
# epoch: 4, loss: 2.129
# epoch: 5, loss: 2.147
# Final loss 2.147
# protein number 573, length 204
# epoch: 1, loss: 1.847
# epoch: 2, loss: 1.846
# epoch: 3, loss: 1.834
# epoch: 4, loss: 1.850
# epoch: 5, loss: 1.959
# Final loss 1.959
# protein number 574, length 97
# epoch: 1, loss: 1.268
# epoch: 2, loss: 1.220
# epoch: 3, loss: 1.229
# epoch: 4, loss: 1.179
# epoch: 5, loss: 1.232
# Final loss 1.232
# protein number 575, length 250
# epoch: 1, loss: 2.094
# epoch: 2, loss: 1.919
# epoch: 3, loss: 2.034
# epoch: 4, loss: 2.021
# epoch: 5, loss: 2.033
# Final loss 2.033
# protein number 576, length 296
# epoch: 1, loss: 1.658
# epoch: 2, loss: 1.581
# epoch: 3, loss: 1.637
# epoch: 4, loss: 1.621
# epoch: 5, loss: 1.625
# Final loss 1.625
# protein number 577, length 390
# epoch: 1, loss: 1.555
# epoch: 2, loss: 1.542
# epoch: 3, loss: 1.532
# epoch: 4, loss: 1.524
# epoch: 5, loss: 1.538
# Final loss 1.538
# protein number 578, length 35
# epoch: 1, loss: 0.210
# epoch: 2, loss: 0.379
# epoch: 3, loss: 0.184
# epoch: 4, loss: 0.182
# epoch: 5, loss: 0.177
# Final loss 0.177
# protein number 579, length 174
# epoch: 1, loss: 1.878
# epoch: 2, loss: 2.096
# epoch: 3, loss: 1.857
# epoch: 4, loss: 1.804
# epoch: 5, loss: 1.846
# Final loss 1.846
# protein number 580, length 157
# epoch: 1, loss: 2.214
# epoch: 2, loss: 2.202
# epoch: 3, loss: 2.217
# epoch: 4, loss: 1.978
# epoch: 5, loss: 2.227
# Final loss 2.227
# protein number 581, length 278
# epoch: 1, loss: 1.825
# epoch: 2, loss: 1.938
# epoch: 3, loss: 1.814
# epoch: 4, loss: 1.907
# epoch: 5, loss: 1.920
# Final loss 1.920
# protein number 582, length 142
# epoch: 1, loss: 1.659
# epoch: 2, loss: 1.611
# epoch: 3, loss: 1.783
# epoch: 4, loss: 1.787
# epoch: 5, loss: 1.612
# Final loss 1.612
# protein number 583, length 313
# epoch: 1, loss: 1.825
# epoch: 2, loss: 1.907
# epoch: 3, loss: 1.746
# epoch: 4, loss: 1.893
# epoch: 5, loss: 1.900
# Final loss 1.900
# protein number 584, length 174
# epoch: 1, loss: 2.056
# epoch: 2, loss: 1.689
# epoch: 3, loss: 1.820
# epoch: 4, loss: 1.687
# epoch: 5, loss: 1.821
# Final loss 1.821
# protein number 585, length 188
# epoch: 1, loss: 2.107
# epoch: 2, loss: 2.119
# epoch: 3, loss: 1.969
# epoch: 4, loss: 2.100
# epoch: 5, loss: 1.976
# Final loss 1.976
# protein number 586, length 158
# epoch: 1, loss: 2.189
# epoch: 2, loss: 2.138
# epoch: 3, loss: 1.730
# epoch: 4, loss: 2.148
# epoch: 5, loss: 2.174
# Final loss 2.174
# protein number 587, length 80
# epoch: 1, loss: 1.449
# epoch: 2, loss: 1.782
# epoch: 3, loss: 1.384
# epoch: 4, loss: 1.091
# epoch: 5, loss: 1.403
# Final loss 1.403
# protein number 588, length 729
# epoch: 1, loss: 1.248
# epoch: 2, loss: 1.170
# epoch: 3, loss: 1.189
# epoch: 4, loss: 1.178
# epoch: 5, loss: 1.186
# Final loss 1.186
# protein number 589, length 328
# epoch: 1, loss: 1.572
# epoch: 2, loss: 1.529
# epoch: 3, loss: 1.527
# epoch: 4, loss: 1.518
# epoch: 5, loss: 1.511
# Final loss 1.511
# protein number 590, length 143
# epoch: 1, loss: 1.825
# epoch: 2, loss: 1.737
# epoch: 3, loss: 1.754
# epoch: 4, loss: 1.588
# epoch: 5, loss: 1.581
# Final loss 1.581
# protein number 591, length 35
# epoch: 1, loss: 0.178
# epoch: 2, loss: 0.345
# epoch: 3, loss: 0.172
# epoch: 4, loss: 0.171
# epoch: 5, loss: 0.171
# Final loss 0.171
# protein number 592, length 112
# epoch: 1, loss: 1.458
# epoch: 2, loss: 1.656
# epoch: 3, loss: 1.624
# epoch: 4, loss: 1.438
# epoch: 5, loss: 1.996
# Final loss 1.996
# protein number 593, length 313
# epoch: 1, loss: 1.770
# epoch: 2, loss: 1.818
# epoch: 3, loss: 1.717
# epoch: 4, loss: 1.793
# epoch: 5, loss: 1.777
# Final loss 1.777
# protein number 594, length 311
# epoch: 1, loss: 1.901
# epoch: 2, loss: 1.810
# epoch: 3, loss: 1.883
# epoch: 4, loss: 1.902
# epoch: 5, loss: 1.898
# Final loss 1.898
# protein number 595, length 174
# epoch: 1, loss: 1.827
# epoch: 2, loss: 1.801
# epoch: 3, loss: 1.777
# epoch: 4, loss: 1.662
# epoch: 5, loss: 1.660
# Final loss 1.660
# protein number 596, length 189
# epoch: 1, loss: 2.014
# epoch: 2, loss: 2.056
# epoch: 3, loss: 1.983
# epoch: 4, loss: 2.039
# epoch: 5, loss: 2.001
# Final loss 2.001
# protein number 597, length 605
# epoch: 1, loss: 1.417
# epoch: 2, loss: 1.385
# epoch: 3, loss: 1.389
# epoch: 4, loss: 1.380
# epoch: 5, loss: 1.354
# Final loss 1.354
# protein number 598, length 143
# epoch: 1, loss: 1.746
# epoch: 2, loss: 2.109
# epoch: 3, loss: 1.835
# epoch: 4, loss: 1.665
# epoch: 5, loss: 1.653
# Final loss 1.653
# protein number 599, length 218
# epoch: 1, loss: 2.106
# epoch: 2, loss: 2.091
# epoch: 3, loss: 2.103
# epoch: 4, loss: 1.942
# epoch: 5, loss: 1.817
# Final loss 1.817
# protein number 600, length 359
# epoch: 1, loss: 1.651
# epoch: 2, loss: 1.641
# epoch: 3, loss: 1.554
# epoch: 4, loss: 1.553
# epoch: 5, loss: 1.604
# Final loss 1.604
# protein number 601, length 729
# epoch: 1, loss: 1.284
# epoch: 2, loss: 1.226
# epoch: 3, loss: 1.259
# epoch: 4, loss: 1.254
# epoch: 5, loss: 1.231
# Final loss 1.231
# protein number 602, length 250
# epoch: 1, loss: 2.036
# epoch: 2, loss: 1.872
# epoch: 3, loss: 1.998
# epoch: 4, loss: 1.999
# epoch: 5, loss: 1.978
# Final loss 1.978
# protein number 603, length 265
# epoch: 1, loss: 1.678
# epoch: 2, loss: 1.742
# epoch: 3, loss: 1.671
# epoch: 4, loss: 1.656
# epoch: 5, loss: 1.661
# Final loss 1.661
# protein number 604, length 189
# epoch: 1, loss: 2.191
# epoch: 2, loss: 2.175
# epoch: 3, loss: 2.095
# epoch: 4, loss: 2.132
# epoch: 5, loss: 2.118
# Final loss 2.118
# protein number 605, length 81
# epoch: 1, loss: 1.631
# epoch: 2, loss: 1.315
# epoch: 3, loss: 1.642
# epoch: 4, loss: 1.656
# epoch: 5, loss: 1.712
# Final loss 1.712
# protein number 606, length 373
# epoch: 1, loss: 1.657
# epoch: 2, loss: 1.605
# epoch: 3, loss: 1.677
# epoch: 4, loss: 1.544
# epoch: 5, loss: 1.574
# Final loss 1.574
# protein number 607, length 235
# epoch: 1, loss: 1.790
# epoch: 2, loss: 1.880
# epoch: 3, loss: 1.741
# epoch: 4, loss: 1.744
# epoch: 5, loss: 1.875
# Final loss 1.875
# protein number 608, length 374
# epoch: 1, loss: 1.793
# epoch: 2, loss: 1.769
# epoch: 3, loss: 1.763
# epoch: 4, loss: 1.627
# epoch: 5, loss: 1.760
# Final loss 1.760
# protein number 609, length 265
# epoch: 1, loss: 1.751
# epoch: 2, loss: 1.917
# epoch: 3, loss: 1.825
# epoch: 4, loss: 1.731
# epoch: 5, loss: 1.730
# Final loss 1.730
# protein number 610, length 142
# epoch: 1, loss: 1.817
# epoch: 2, loss: 1.630
# epoch: 3, loss: 1.792
# epoch: 4, loss: 1.788
# epoch: 5, loss: 2.052
# Final loss 2.052
# protein number 611, length 189
# epoch: 1, loss: 2.193
# epoch: 2, loss: 1.983
# epoch: 3, loss: 1.949
# epoch: 4, loss: 2.139
# epoch: 5, loss: 2.183
# Final loss 2.183
# protein number 612, length 250
# epoch: 1, loss: 1.926
# epoch: 2, loss: 1.898
# epoch: 3, loss: 2.033
# epoch: 4, loss: 2.008
# epoch: 5, loss: 2.021
# Final loss 2.021
# protein number 613, length 402
# epoch: 1, loss: 1.534
# epoch: 2, loss: 1.579
# epoch: 3, loss: 1.516
# epoch: 4, loss: 1.515
# epoch: 5, loss: 1.565
# Final loss 1.565
# protein number 614, length 66
# epoch: 1, loss: 0.894
# epoch: 2, loss: 0.839
# epoch: 3, loss: 0.846
# epoch: 4, loss: 0.832
# epoch: 5, loss: 0.795
# Final loss 0.795
# protein number 615, length 81
# epoch: 1, loss: 1.034
# epoch: 2, loss: 1.301
# epoch: 3, loss: 1.261
# epoch: 4, loss: 1.022
# epoch: 5, loss: 1.635
# Final loss 1.635
# protein number 616, length 112
# epoch: 1, loss: 1.627
# epoch: 2, loss: 1.947
# epoch: 3, loss: 1.422
# epoch: 4, loss: 1.416
# epoch: 5, loss: 1.925
# Final loss 1.925
# protein number 617, length 343
# epoch: 1, loss: 1.769
# epoch: 2, loss: 1.819
# epoch: 3, loss: 1.728
# epoch: 4, loss: 1.740
# epoch: 5, loss: 1.807
# Final loss 1.807
# protein number 618, length 66
# epoch: 1, loss: 0.791
# epoch: 2, loss: 1.012
# epoch: 3, loss: 0.781
# epoch: 4, loss: 0.757
# epoch: 5, loss: 0.740
# Final loss 0.740
# protein number 619, length 143
# epoch: 1, loss: 1.777
# epoch: 2, loss: 1.973
# epoch: 3, loss: 1.961
# epoch: 4, loss: 1.586
# epoch: 5, loss: 1.747
# Final loss 1.747
# protein number 620, length 66
# epoch: 1, loss: 0.820
# epoch: 2, loss: 0.798
# epoch: 3, loss: 0.805
# epoch: 4, loss: 0.777
# epoch: 5, loss: 0.775
# Final loss 0.775
# protein number 621, length 205
# epoch: 1, loss: 1.847
# epoch: 2, loss: 1.959
# epoch: 3, loss: 1.670
# epoch: 4, loss: 1.811
# epoch: 5, loss: 1.824
# Final loss 1.824
# protein number 622, length 143
# epoch: 1, loss: 1.748
# epoch: 2, loss: 1.936
# epoch: 3, loss: 1.574
# epoch: 4, loss: 1.578
# epoch: 5, loss: 1.745
# Final loss 1.745
# protein number 623, length 127
# epoch: 1, loss: 2.258
# epoch: 2, loss: 2.237
# epoch: 3, loss: 2.221
# epoch: 4, loss: 2.216
# epoch: 5, loss: 2.221
# Final loss 2.221
# protein number 624, length 128
# epoch: 1, loss: 2.235
# epoch: 2, loss: 2.231
# epoch: 3, loss: 2.235
# epoch: 4, loss: 2.230
# epoch: 5, loss: 2.224
# Final loss 2.224
# protein number 625, length 50
# epoch: 1, loss: 0.727
# epoch: 2, loss: 1.211
# epoch: 3, loss: 0.741
# epoch: 4, loss: 1.205
# epoch: 5, loss: 1.124
# Final loss 1.124
# protein number 626, length 753
# epoch: 1, loss: 1.212
# epoch: 2, loss: 1.156
# epoch: 3, loss: 1.152
# epoch: 4, loss: 1.122
# epoch: 5, loss: 1.122
# Final loss 1.122
# protein number 627, length 112
# epoch: 1, loss: 1.782
# epoch: 2, loss: 1.462
# epoch: 3, loss: 1.441
# epoch: 4, loss: 1.935
# epoch: 5, loss: 1.980
# Final loss 1.980
# protein number 628, length 293
# epoch: 1, loss: 1.613
# epoch: 2, loss: 1.583
# epoch: 3, loss: 1.624
# epoch: 4, loss: 1.620
# epoch: 5, loss: 1.572
# Final loss 1.572
# protein number 629, length 81
# epoch: 1, loss: 1.359
# epoch: 2, loss: 1.062
# epoch: 3, loss: 1.342
# epoch: 4, loss: 1.047
# epoch: 5, loss: 1.745
# Final loss 1.745
# protein number 630, length 128
# epoch: 1, loss: 2.251
# epoch: 2, loss: 2.226
# epoch: 3, loss: 2.260
# epoch: 4, loss: 2.265
# epoch: 5, loss: 2.263
# Final loss 2.263
# protein number 631, length 325
# epoch: 1, loss: 1.670
# epoch: 2, loss: 1.626
# epoch: 3, loss: 1.632
# epoch: 4, loss: 1.626
# epoch: 5, loss: 1.704
# Final loss 1.704

# %% [markdown]
# ## Validation

# %%
data = scn.load(casp_version=7, with_pytorch="dataloaders", 
                seq_as_onehot=True, aggregate_model_input=False,
               batch_size=1)
checkpoint = torch.load('checkpoint.pth')
model.load_state_dict(checkpoint['state_dict'])
model.eval()
count = 0
for batch in tqdm(data['valid-10']):
    seqs, evos, angs, masks, dmats, dmat_masks = get_seq_features(batch)
    #print(seqs.shape, evos.shape, angs.shape, masks.shape)
    # print(dmats.shape, dmat_masks.shape)
    #print(dmats)
    # generate sequence block with L×L×f
    seq_len = seqs.size(dim=1)
    seqs_evos = torch.cat((seqs, evos), 2)
    #print(seqs_evos.shape)
    seq_block = torch.tensor(seq_len*[seqs_evos.tolist()])
    #print(seq_block.shape)
    seq_block = torch.transpose(seq_block, 0, 1)
    #seq_block = einops.rearrange(seq_block, 'l b h f -> b l h f')
    seq_block_t = torch.transpose(seq_block, 1, 2)
    seq_block = torch.cat((seq_block_t, seq_block), 3)

    evo_block = torch.tensor(seq_len*[evos.tolist()])
    evo_block = torch.transpose(evo_block, 0, 1)
    #evo_block = einops.rearrange(evo_block, 'l b h f -> b l h f')
    evo_block_t = torch.transpose(evo_block, 1, 2)
    final_block = torch.cat((seq_block, evo_block-evo_block_t, 
                             evo_block * evo_block_t), 3)
    #print(final_block.shape)
    valid_test(final_block, dmats, dmat_masks, device, model)
    # t_short_acc += short_acc
    # t_medium_acc += medium_acc
    # t_long_acc += long_acc
    #print('protein number {}, length {}'.format(count, seq_len))
    del seq_block
    del seq_block_t
    del final_block
    del evo_block
    del evo_block_t
    gc.collect()
    
    count += 1
    # if count == 5:
    #     break
    #break

print('Validation short accuracy L: {:.3f}'.format(recall_short_L/count))
print('Validation short accuracy L/2: {:.3f}'.format(recall_short_L_2/count))
print('Validation short accuracy L/5: {:.3f}'.format(recall_short_L_5/count))
print('Validation medium accuracy L: {:.3f}'.format(recall_medium_L/count))
print('Validation medium accuracy L/2: {:.3f}'.format(recall_medium_L_2/count))
print('Validation medium accuracy L/5: {:.3f}'.format(recall_medium_L_5/count))
print('Validation long accuracy L: {:.3f}'.format(recall_long_L/count))
print('Validation long accuracy L/2: {:.3f}'.format(recall_long_L_2/count))
print('Validation long accuracy L/5: {:.3f}'.format(recall_long_L_5/count))
# Out:
# SidechainNet was loaded from ./sidechainnet_data/sidechainnet_casp7_30.pkl.
# 100%|██████████| 32/32 [03:11<00:00,  5.97s/it]
# Validation short accuracy L: 0.938
# Validation short accuracy L/2: 0.938
# Validation short accuracy L/5: 0.719
# Validation medium accuracy L: 0.875
# Validation medium accuracy L/2: 0.781
# Validation medium accuracy L/5: 0.562
# Validation long accuracy L: 0.875
# Validation long accuracy L/2: 0.844
# Validation long accuracy L/5: 0.594

# %% [markdown]
# ## Testing

# %%
count = 0
recall_short_L = 0
recall_short_L_2 = 0
recall_short_L_5 = 0
recall_medium_L = 0
recall_medium_L_2 = 0
recall_medium_L_5 = 0
recall_long_L = 0
recall_long_L_2 = 0
recall_long_L_5 = 0
for batch in tqdm(data['test']):
    seqs, evos, angs, masks, dmats, dmat_masks = get_seq_features(batch)
    # print(seqs.shape, evos.shape, angs.shape, masks.shape)
    # print(dmats.shape, dmat_masks.shape)

    # generate sequence block with L×L×f
    seq_len = seqs.size(dim=1)
    seqs_evos = torch.cat((seqs, evos), 2)
    #print(seqs_evos.shape)
    seq_block = torch.tensor(seq_len*[seqs_evos.tolist()])
    #print(seq_block.shape)
    seq_block = torch.transpose(seq_block, 0, 1)
    #seq_block = einops.rearrange(seq_block, 'l b h f -> b l h f')
    seq_block_t = torch.transpose(seq_block, 1, 2)
    seq_block = torch.cat((seq_block_t, seq_block), 3)

    evo_block = torch.tensor(seq_len*[evos.tolist()])
    evo_block = torch.transpose(evo_block, 0, 1)
    #evo_block = einops.rearrange(evo_block, 'l b h f -> b l h f')
    evo_block_t = torch.transpose(evo_block, 1, 2)
    final_block = torch.cat((seq_block, evo_block-evo_block_t, 
                             evo_block * evo_block_t), 3)
    #print(final_block.shape)
    valid_test(final_block, dmats, dmat_masks, device, model)
    
    #print('protein number {}, length {}'.format(count, seq_len))
    del seq_block
    del seq_block_t
    del final_block
    del evo_block
    del evo_block_t
    gc.collect()
    
    count += 1
    #break

print('Test short accuracy L: {:.3f}'.format(recall_short_L/count))
print('Test short accuracy L/2: {:.3f}'.format(recall_short_L_2/count))
print('Test short accuracy L/5: {:.3f}'.format(recall_short_L_5/count))
print('Test medium accuracy L: {:.3f}'.format(recall_medium_L/count))
print('Test medium accuracy L/2: {:.3f}'.format(recall_medium_L_2/count))
print('Test medium accuracy L/5: {:.3f}'.format(recall_medium_L_5/count))
print('Test long accuracy L: {:.3f}'.format(recall_long_L/count))
print('Test long accuracy L/2: {:.3f}'.format(recall_long_L_2/count))
print('Test long accuracy L/5: {:.3f}'.format(recall_long_L_5/count))
# Out:
# 100%|██████████| 93/93 [08:32<00:00,  5.52s/it]
# Test short accuracy L: 0.989
# Test short accuracy L/2: 0.989
# Test short accuracy L/5: 0.828
# Test medium accuracy L: 0.989
# Test medium accuracy L/2: 0.968
# Test medium accuracy L/5: 0.710
# Test long accuracy L: 0.989
# Test long accuracy L/2: 0.892
# Test long accuracy L/5: 0.645
